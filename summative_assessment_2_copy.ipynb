# %% [markdown]
# <a href="https://colab.research.google.com/github/Gautam-Chauhan/DeepLearningCoursework2/blob/main/summative_assessment_2_copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning
# ## Summative assessment
# ### Coursework 2

# %% [markdown]
# #### Instructions
#
# This coursework is released on **5th March 9.00 (UK time)** and is due by **26th March 9.00 (UK time)**. It is worth **50%** of your overall mark. There are 4 questions in this assessment, and a total of 50 marks are available. **You should attempt to answer all questions.** In addition to the total number of marks shown per question below, an additional 5 marks is available for presentation and clarity/quality of code.
#
# This assessment assesses your ability to implement and analyse implementations of Bayesian neural networks (BNNs). In particular, you will explore techniques for examining the performance and calibration properties of the trained models.
#
# Throughout the development of your models in this assessment you should use the high level Keras `compile` and `fit` APIs to train your models (no custom training loops), making use of layer and model subclassing as appropriate.
#
# You can make imports as and when you need them throughout the notebook, and add code cells where necessary. Make sure your notebook executes correctly in sequence before submitting.
#
# #### Submission instructions
#
# The submission for this assessment will consist of a notebook (.ipynb file) and PDF report.
#
# Ensure your notebook executes correctly in order. Save your notebook .ipynb file **after you have executed it** (so that outputs are all showing). It is recommended to also submit a PDF/HTML copy of your executed notebook, in case the .ipynb file is corrupted for some reason.
#
# Upload a zip file containing your notebook and separate PDF/HTML file(s) by the deadline above.

# %% [markdown]
# This assignment must be attempted individually; your submission must be your own, unaided work. Candidates are prohibited from discussing assessed coursework, and must abide by [Imperial College’s rules](https://www.imperial.ac.uk/media/imperial-college/administration-and-support-services/registry/academic-governance/public/academic-policy/academic-integrity/Examination-and-assessments---academic-integrity.pdf) regarding academic integrity and plagiarism. Unless specifically authorised within the assignment instructions, the submission of output from [generative AI tools](https://www.imperial.ac.uk/about/leadership-and-strategy/provost/vice-provost-education/generative-ai-tools-guidance/) (e.g., ChatGPT) for assessed coursework is prohibited. Violations will be treated as an examination offence. Enabling other candidates to plagiarise your work constitutes an examination offence. To ensure quality assurance is maintained, departments may choose to invite a random selection of students to an ‘authenticity interview’ on their submitted assessments.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# You will need the following imports for this assessment. You can make additional imports when you need them

import os
import torch
os.environ["KERAS_BACKEND"] = "torch"

import keras
from keras import ops
from keras import backend
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import scipy

from keras.models import Sequential, Model
from keras.layers import Input, Conv2D, Dense
from keras import regularizers

from torchvision.transforms import v2

import time

# %% [markdown]
# #### The CIFAR-10 dataset
# In this assignment, you will use the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html). This image dataset has 60,000 32x32 colour images in 10 classes, with 6,000 images per class. There are 50,000 training images and 10,000 test images.
#
# * A. Krizhevsky (2009), "Learning Multiple Layers of Features from Tiny Images", technical report.

# %% [markdown]
# #### Performance and calibration of classifier models
#
# Your task in this assessment is image classification. The models you will develop will take an input image and return a prediction for which class the image belongs to. In this assessment you will study the performance and calibration of classification models, including Bayesian neural networks (BNNs).
#
# In question 1 you will prepare the dataset for training your models, and train a baseline deterministic model as well as a BNN variant using the MC Dropout technique. In question 2 you will develop and train another BNN variant, this time using a technique known as SWAG. In question 3 you will examine the calibration properties of the models you have trained.
#
# The training algorithm and models you develop will potentially require several hyperparameter choices, and it is up to you to select hyperparameters according to criteria of your choice. It is not necessary to include all experiments carried out in code in this notebook. You only need to include any custom code that you have written, and the code for the final choice of hyperparameters (in order to avoid overly long notebook submissions). In question 4 you will write a report detailing the experiments carried out.

# %% [markdown]
# ### Question 1 (Total 10 marks)

# %% [markdown]
# a) Download/load the train and test splits for the CIFAR-10 dataset using the `keras.datasets` module. Create a separate validation set by randomly selecting 20% of the training data examples.
#
# Store the data in PyTorch DataLoaders or TensorFlow Datasets ready for training. There should be one Dataset/DataLoader each for the training, validation and test splits. Your data processing pipeline for the training set should include the following data augmentation techniques:
#
# * Random crop with 4-pixel padding
# * Random horizontal flip
#
# Demonstrate that your datasets are working correctly by sampling some images from the training dataset and displaying them.
#
# **(2 marks)**

# %%
# Import CIFAR10 dataset
(x_train,y_train),(x_test,y_test) = keras.datasets.cifar10.load_data()
# Split training set into separate training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state=1)
# Check sizes
print(f"Training size: {x_train.shape}")
print(f"Validation size: {x_val.shape}")
print(f"Test size: {x_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Training size: (40000, 32, 32, 3)
# Validation size: (10000, 32, 32, 3)
# Test size: (10000, 32, 32, 3)

# %%
class TrainDataset(torch.utils.data.Dataset):

  def __init__(self, inputs, outputs):
    self.augmentations = v2.Compose([v2.RandomCrop(size=32,padding=4),
                                    v2.RandomHorizontalFlip(p=0.5)])
    self.inputs = torch.tensor(inputs)
    self.outputs = torch.tensor(outputs)

  def __len__(self):
    return len(self.inputs)

  def __getitem__(self, idx):
    # Apply augmentations (permute as RandomCrop requires channels first)
    x = self.inputs[idx,:,:,:]/255
    x = x.permute(2,0,1)
    x = self.augmentations(x)
    x = x.permute(1,2,0)
    y = self.outputs[idx]
    return x, y

# %%
class EvalDataset(torch.utils.data.Dataset):

  def __init__(self, inputs, outputs):
    self.inputs = torch.tensor(inputs)
    self.outputs = torch.tensor(outputs)

  def __len__(self):
    return len(self.inputs)

  def __getitem__(self,idx):
    x = self.inputs[idx,:,:,:]/255
    y = self.outputs[idx]
    return x, y

# %%
train_data_loader = torch.utils.data.DataLoader(TrainDataset(x_train,y_train),batch_size=64,shuffle=True)
val_data_loader = torch.utils.data.DataLoader(EvalDataset(x_val,y_val),batch_size=64,shuffle=False)
test_data_loader = torch.utils.data.DataLoader(EvalDataset(x_test,y_test),batch_size=64,shuffle=False)

# %%
images, labels = next(iter(train_data_loader))

# %%
display_images = images[10:13,:,:,:]
fig,ax = plt.subplots(1,3)
ax[0].imshow(display_images[0].cpu().numpy())
ax[1].imshow(display_images[1].cpu().numpy())
ax[2].imshow(display_images[2].cpu().numpy())

# %% [markdown]
# b) Implement a ResNet20-style convolutional neural network classifier model for the CIFAR-10 dataset. Your implementation should be entirely in Keras, using the Sequential API and layer subclassing as necessary. The full spec for the model is as follows:
#
# * Input Tensor of shape `(32, 32, 3)`
# * Conv layer with $c=16$ filters, kernel size $k=3$, stride $s=1$, ReLU activation
# * **Stage 1**: 3 residual blocks with $c=16$ filters and stride $s=1$
#     * Each residual block with $c$ filters and stride $s$ is constructed as follows:
#         * Conv layer with $c$ filters, $k=3$, stride $s$, ReLU activation
#         * Conv layer with $c$ filters, $k=3$, stride 1, no activation
#         * Skip connection that adds the layer input to the output of the previous conv layer
#         * ReLU activation applied to the output of the skip connection
# * **Stage 2**: 3 residual blocks with $c=32$ filters
#     * Block 1: use $s=2$
#         * Note that whenever the number of filters in the layer input is not equal to $c$ (as will be the case for this block), then it will not be possible to apply the skip connection. In this case, add the following convolutional layer as part of the skip connection:
#             * Conv layer with $c$ filters, $k=1$, stride $s$, "VALID" padding
#     * Blocks 2 & 3: use $s=1$
# * **Stage 3**: 3 residual blocks with $c=64$ filters
#     * Block 1: use $s=2$
#     * Blocks 2 & 3: use $s=1$
# * Spatial global average pooling (reduces out spatial dimensions)
# * Dense layer with 10 output neurons, no activation, "He normal" initialisation
#
# All convolutional layers should use "SAME" padding (unless otherwise indicated), L2 (kernel) weight regularisation, and the "He normal" initializer.
#
# Print the model summary.
#
# **(3 marks)**

# %%
@keras.saving.register_keras_serializable(package="MyLayers")
class ResidualBlock(keras.layers.Layer):

  def __init__(self,filters,stride,extra_conv=False,**kwargs):
    super().__init__(**kwargs)
    self.filters = filters
    self.stride = stride
    self.extra_conv = extra_conv

  # get_config method necessary for saving and loading model properly
  def get_config(self):
    config = super().get_config()
    config.update(
        {
            "filters": self.filters,
            "stride": self.stride,
            "extra_conv": self.extra_conv,
        }
      )
    return config

  def build(self):
    self.conv1 = keras.layers.Conv2D(filters=self.filters,kernel_size=3,
                                     strides=self.stride,padding="same",
                                     kernel_regularizer=regularizers.L2(),
                                     kernel_initializer="he_normal")
    self.relu1 = keras.layers.ReLU()
    self.conv2 = keras.layers.Conv2D(filters=self.filters,kernel_size=3,
                                     strides=1,padding="same",
                                     kernel_regularizer=regularizers.L2(),
                                     kernel_initializer="he_normal")
    if self.extra_conv == True:
      self.conv3 = keras.layers.Conv2D(filters=self.filters,kernel_size=1,
                                       strides=self.stride,padding="valid",
                                       kernel_regularizer=regularizers.L2(),
                                       kernel_initializer="he_normal")

    self.relu2 = keras.layers.ReLU()

  def call(self,inputs):
    x = self.conv1(inputs)
    x = self.relu1(x)
    x = self.conv2(x)
    if self.extra_conv:
      x = x + self.conv3(inputs)
    else:
      x = x + inputs
    x = self.relu2(x)
    return x

# %%
def get_model():
  model = keras.Sequential([keras.layers.Input(shape=(32,32,3)),
                            keras.layers.Conv2D(filters=16,kernel_size=3,
                                    strides=1,padding="same",
                                    kernel_regularizer=regularizers.L2(),
                                    kernel_initializer="he_normal"),
                          keras.layers.ReLU(),
                          ResidualBlock(filters=16,stride=1),
                          ResidualBlock(filters=16,stride=1),
                          ResidualBlock(filters=16,stride=1),
                          ResidualBlock(filters=32,stride=2,extra_conv=True),
                          ResidualBlock(filters=32,stride=1),
                          ResidualBlock(filters=32,stride=1),
                          ResidualBlock(filters=64,stride=2,extra_conv=True),
                          ResidualBlock(filters=64,stride=1),
                          ResidualBlock(filters=64,stride=1),
                          keras.layers.GlobalAveragePooling2D(),
                          keras.layers.Dense(10,kernel_initializer="he_normal")

  ])
  return model

# %%
model = get_model()

# %%
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ (None, 32, 32, 16)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_1                │ (None, 32, 32, 16)     │         4,640 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_2                │ (None, 32, 32, 16)     │         4,640 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_3                │ (None, 16, 16, 32)     │        14,432 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_4                │ (None, 16, 16, 32)     │        18,496 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_5                │ (None, 16, 16, 32)     │        18,496 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_6                │ (None, 8, 8, 64)       │        57,536 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_7                │ (None, 8, 8, 64)       │        73,856 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_8                │ (None, 8, 8, 64)       │        73,856 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 271,690 (1.04 MB)
#  Trainable params: 271,690 (1.04 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# c) Train your model on the CIFAR-10 dataset using the high-level Keras API for maximum 200 epochs, using SGD with momentum. Your training run should track the categorical accuracy metric, and save the best model according to the *accuracy* (correction) on the validation set. You should select any hyperparameters to try to maximise the validation accuracy of the model.
#
# Compute and print out the final evaluation of your model on the test set.
#
# _Make sure to save your trained model, as it will be used in later questions in this assessment._
#
# **(2 marks)**

# %% [markdown]
# Initial attempt (saving was unsuccessful) - DO NOT RERUN FOLLOWING TWO CELLS:

# %%
model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.01,momentum=0.2,clipnorm=1.0),
              loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = [keras.metrics.SparseCategoricalAccuracy()]
)

# %%
history = model.fit(train_data_loader, epochs=200, validation_data=val_data_loader)
# Out:
# Epoch 1/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 102ms/step - loss: 16.3526 - sparse_categorical_accuracy: 0.2330 - val_loss: 14.5020 - val_sparse_categorical_accuracy: 0.3160
# Epoch 2/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 13.2842 - sparse_categorical_accuracy: 0.3124 - val_loss: 12.1148 - val_sparse_categorical_accuracy: 0.3506
# Epoch 3/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 11.1947 - sparse_categorical_accuracy: 0.3378 - val_loss: 10.2763 - val_sparse_categorical_accuracy: 0.3628
# Epoch 4/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 9.5642 - sparse_categorical_accuracy: 0.3579 - val_loss: 8.7289 - val_sparse_categorical_accuracy: 0.4079
# Epoch 5/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 8.2536 - sparse_categorical_accuracy: 0.3714 - val_loss: 7.6088 - val_sparse_categorical_accuracy: 0.3946
# Epoch 6/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 7.1637 - sparse_categorical_accuracy: 0.3839 - val_loss: 6.6020 - val_sparse_categorical_accuracy: 0.4057
# Epoch 7/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 6.2803 - sparse_categorical_accuracy: 0.3846 - val_loss: 5.8609 - val_sparse_categorical_accuracy: 0.4089
# Epoch 8/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 5.5481 - sparse_categorical_accuracy: 0.3897 - val_loss: 5.1757 - val_sparse_categorical_accuracy: 0.4252
# Epoch 9/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 4.9390 - sparse_categorical_accuracy: 0.3971 - val_loss: 4.5526 - val_sparse_categorical_accuracy: 0.4411
# Epoch 10/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 4.4236 - sparse_categorical_accuracy: 0.4051 - val_loss: 4.1199 - val_sparse_categorical_accuracy: 0.4391
# Epoch 11/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 4.0078 - sparse_categorical_accuracy: 0.4074 - val_loss: 3.7506 - val_sparse_categorical_accuracy: 0.4266
# Epoch 12/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 3.6556 - sparse_categorical_accuracy: 0.4124 - val_loss: 3.4514 - val_sparse_categorical_accuracy: 0.4296
# Epoch 13/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 3.3726 - sparse_categorical_accuracy: 0.4133 - val_loss: 3.1207 - val_sparse_categorical_accuracy: 0.4646
# Epoch 14/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss:
200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.6631 - sparse_categorical_accuracy: 0.5710 - val_loss: 1.5795 - val_sparse_categorical_accuracy: 0.5951
# Epoch 95/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6616 - sparse_categorical_accuracy: 0.5694 - val_loss: 1.6036 - val_sparse_categorical_accuracy: 0.5987
# Epoch 96/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6637 - sparse_categorical_accuracy: 0.5723 - val_loss: 1.6019 - val_sparse_categorical_accuracy: 0.5910
# Epoch 97/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6566 - sparse_categorical_accuracy: 0.5755 - val_loss: 1.5856 - val_sparse_categorical_accuracy: 0.6063
# Epoch 98/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.6516 - sparse_categorical_accuracy: 0.5756 - val_loss: 1.6411 - val_sparse_categorical_accuracy: 0.5755
# Epoch 99/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6549 - sparse_categorical_accuracy: 0.5748 - val_loss: 1.6061 - val_sparse_categorical_accuracy: 0.5925
# Epoch 100/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6483 - sparse_categorical_accuracy: 0.5777 - val_loss: 1.7075 - val_sparse_categorical_accuracy: 0.5607
# Epoch 101/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6519 - sparse_categorical_accuracy: 0.5817 - val_loss: 1.6285 - val_sparse_categorical_accuracy: 0.5792
# Epoch 102/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.6475 - sparse_categorical_accuracy: 0.5813 - val_loss: 1.5989 - val_sparse_categorical_accuracy: 0.5994
# Epoch 103/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.6497 - sparse_categorical_accuracy: 0.5792 - val_loss: 1.6209 - val_sparse_categorical_accuracy: 0.5903
# Epoch 104/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.6439 - sparse_categorical_accuracy: 0.5803 - val_loss: 1.6223 - val_sparse_categorical_accuracy: 0.5831
# Epoch 105/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.6421 - sparse_categorical_accuracy: 0.5811 - val_loss: 1.6490 - val_sparse_categorical_accuracy: 0.5814
# Epoch 106/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.6419 - sparse_categorical_accuracy: 0.5816 - val_loss: 1.5972 - val_sparse_categorical_accuracy: 0.6039
# Epoch 107/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.6364 - sparse_categorical_accuracy: 0.5847 - val_loss: 1.6455 - val_sparse_categorical_accuracy: 0.5894
# Epoch 108/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.6369 - sparse_categorical_accuracy: 0.5836 - val_loss: 1.5384 - val_sparse_categorical_accuracy: 0.6276
# Epoch 109/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6339 - sparse_categorical_accuracy: 0.5872 - val_loss: 1.6499 - val_sparse_categorical_accuracy: 0.5916
# Epoch 110/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.6308 - sparse_categorical_accuracy: 0.5889 - val_loss: 1.8015 - val_sparse_categorical_accuracy: 0.5565
# Epoch 111/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6294 - sparse_categorical_accuracy: 0.5895 - val_loss: 1.5330 - val_sparse_categorical_accuracy: 0.6248
# Epoch 112/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.6238 - sparse_categorical_accuracy: 0.5883 - val_loss: 1.5768 - val_sparse_categorical_accuracy: 0.6114
# Epoch 113/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6259 - sparse_categorical_accuracy: 0.5886 - val_loss: 1.5803 - val_sparse_categorical_accuracy: 0.6063
# Epoch 114/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6214 - sparse_categorical_accuracy: 0.5957 - val_loss: 1.5482 - val_sparse_categorical_accuracy: 0.6163
# Epoch 115/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6167 - sparse_categorical_accuracy: 0.5924 - val_loss: 1.6006 - val_sparse_categorical_accuracy: 0.5978
# Epoch 116/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.6133 - sparse_categorical_accuracy: 0.5929 - val_loss: 1.6750 - val_sparse_categorical_accuracy: 0.5823
# Epoch 117/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6165 - sparse_categorical_accuracy: 0.5942 - val_loss: 1.7305 - val_sparse_categorical_accuracy: 0.5549
# Epoch 118/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6135 - sparse_categorical_accuracy: 0.5950 - val_loss: 1.6560 - val_sparse_categorical_accuracy: 0.5780
# Epoch 119/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.5949 - val_loss: 1.5373 - val_sparse_categorical_accuracy: 0.6148
# Epoch 120/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6081 - sparse_categorical_accuracy: 0.5988 - val_loss: 1.5812 - val_sparse_categorical_accuracy: 0.6083
# Epoch 121/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.6077 - sparse_categorical_accuracy: 0.5987 - val_loss: 1.7016 - val_sparse_categorical_accuracy: 0.5708
# Epoch 122/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.6049 - sparse_categorical_accuracy: 0.5996 - val_loss: 1.5367 - val_sparse_categorical_accuracy: 0.6158
# Epoch 123/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.5990 - sparse_categorical_accuracy: 0.6023 - val_loss: 1.5414 - val_sparse_categorical_accuracy: 0.6239
# Epoch 124/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5987 - sparse_categorical_accuracy: 0.5991 - val_loss: 1.5170 - val_sparse_categorical_accuracy: 0.6284
# Epoch 125/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5976 - sparse_categorical_accuracy: 0.6015 - val_loss: 1.5405 - val_sparse_categorical_accuracy: 0.6229
# Epoch 126/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.5946 - sparse_categorical_accuracy: 0.6000 - val_loss: 1.5612 - val_sparse_categorical_accuracy: 0.6136
# Epoch 127/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.5883 - sparse_categorical_accuracy: 0.6008 - val_loss: 1.6497 - val_sparse_categorical_accuracy: 0.5855
# Epoch 128/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.5856 - sparse_categorical_accuracy: 0.6051 - val_loss: 1.4860 - val_sparse_categorical_accuracy: 0.6405
# Epoch 129/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5846 - sparse_categorical_accuracy: 0.6062 - val_loss: 1.5823 - val_sparse_categorical_accuracy: 0.6135
# Epoch 130/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5811 - sparse_categorical_accuracy: 0.6074 - val_loss: 1.6241 - val_sparse_categorical_accuracy: 0.5895
# Epoch 131/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5813 - sparse_categorical_accuracy: 0.6082 - val_loss: 1.5029 - val_sparse_categorical_accuracy: 0.6363
# Epoch 132/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5760 - sparse_categorical_accuracy: 0.6089 - val_loss: 1.5660 - val_sparse_categorical_accuracy: 0.6180
# Epoch 133/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5756 - sparse_categorical_accuracy: 0.6051 - val_loss: 1.5851 - val_sparse_categorical_accuracy: 0.6025
# Epoch 134/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5717 - sparse_categorical_accuracy: 0.6119 - val_loss: 1.5303 - val_sparse_categorical_accuracy: 0.6237
# Epoch 135/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.5722 - sparse_categorical_accuracy: 0.6077 - val_loss: 1.5140 - val_sparse_categorical_accuracy: 0.6299
# Epoch 136/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.5691 - sparse_categorical_accuracy: 0.6099 - val_loss: 1.6235 - val_sparse_categorical_accuracy: 0.6065
# Epoch 137/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5649 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.6431 - val_sparse_categorical_accuracy: 0.5884
# Epoch 138/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5652 - sparse_categorical_accuracy: 0.6104 - val_loss: 1.4868 - val_sparse_categorical_accuracy: 0.6369
# Epoch 139/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5578 - sparse_categorical_accuracy: 0.6125 - val_loss: 1.5800 - val_sparse_categorical_accuracy: 0.6040
# Epoch 140/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.5582 - sparse_categorical_accuracy: 0.6155 - val_loss: 1.7518 - val_sparse_categorical_accuracy: 0.5667
# Epoch 141/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5618 - sparse_categorical_accuracy: 0.6115 - val_loss: 1.5231 - val_sparse_categorical_accuracy: 0.6255
# Epoch 142/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.5558 - sparse_categorical_accuracy: 0.6121 - val_loss: 1.4964 - val_sparse_categorical_accuracy: 0.6379
# Epoch 143/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.5580 - sparse_categorical_accuracy: 0.6146 - val_loss: 1.7135 - val_sparse_categorical_accuracy: 0.5715
# Epoch 144/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5562 - sparse_categorical_accuracy: 0.6140 - val_loss: 1.5003 - val_sparse_categorical_accuracy: 0.6389
# Epoch 145/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5511 - sparse_categorical_accuracy: 0.6193 - val_loss: 1.6004 - val_sparse_categorical_accuracy: 0.5998
# Epoch 146/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5543 - sparse_categorical_accuracy: 0.6181 - val_loss: 1.5169 - val_sparse_categorical_accuracy: 0.6283
# Epoch 147/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5491 - sparse_categorical_accuracy: 0.6184 - val_loss: 1.4628 - val_sparse_categorical_accuracy: 0.6494
# Epoch 148/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.5492 - sparse_categorical_accuracy: 0.6188 - val_loss: 1.4821 - val_sparse_categorical_accuracy: 0.6451
# Epoch 149/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5466 - sparse_categorical_accuracy: 0.6198 - val_loss: 1.5766 - val_sparse_categorical_accuracy: 0.6046
# Epoch 150/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.5415 - sparse_categorical_accuracy: 0.6208 - val_loss: 1.4722 - val_sparse_categorical_accuracy: 0.6431
# Epoch 151/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5427 - sparse_categorical_accuracy: 0.6185 - val_loss: 1.4802 - val_sparse_categorical_accuracy: 0.6435
# Epoch 152/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.5434 - sparse_categorical_accuracy: 0.6196 - val_loss: 1.5000 - val_sparse_categorical_accuracy: 0.6385
# Epoch 153/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.5370 - sparse_categorical_accuracy: 0.6220 - val_loss: 1.4838 - val_sparse_categorical_accuracy: 0.6367
# Epoch 154/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.5343 - sparse_categorical_accuracy: 0.6235 - val_loss: 1.4371 - val_sparse_categorical_accuracy: 0.6583
# Epoch 155/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5376 - sparse_categorical_accuracy: 0.6240 - val_loss: 1.4700 - val_sparse_categorical_accuracy: 0.6420
# Epoch 156/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5347 - sparse_categorical_accuracy: 0.6260 - val_loss: 1.6010 - val_sparse_categorical_accuracy: 0.6112
# Epoch 157/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.5341 - sparse_categorical_accuracy: 0.6248 - val_loss: 1.5508 - val_sparse_categorical_accuracy: 0.6237
# Epoch 158/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.5344 - sparse_categorical_accuracy: 0.6259 - val_loss: 1.7328 - val_sparse_categorical_accuracy: 0.5783
# Epoch 159/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.5330 - sparse_categorical_accuracy: 0.6267 - val_loss: 1.4927 - val_sparse_categorical_accuracy: 0.6463
# Epoch 160/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5335 - sparse_categorical_accuracy: 0.6274 - val_loss: 1.4946 - val_sparse_categorical_accuracy: 0.6366
# Epoch 161/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5286 - sparse_categorical_accuracy: 0.6289 - val_loss: 1.5142 - val_sparse_categorical_accuracy: 0.6342
# Epoch 162/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.5283 - sparse_categorical_accuracy: 0.6256 - val_loss: 1.4984 - val_sparse_categorical_accuracy: 0.6332
# Epoch 163/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5279 - sparse_categorical_accuracy: 0.6296 - val_loss: 1.4728 - val_sparse_categorical_accuracy: 0.6511
# Epoch 164/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5280 - sparse_categorical_accuracy: 0.6297 - val_loss: 1.5886 - val_sparse_categorical_accuracy: 0.6100
# Epoch 165/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5244 - sparse_categorical_accuracy: 0.6293 - val_loss: 1.5096 - val_sparse_categorical_accuracy: 0.6307
# Epoch 166/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5235 - sparse_categorical_accuracy: 0.6281 - val_loss: 1.5968 - val_sparse_categorical_accuracy: 0.6018
# Epoch 167/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5237 - sparse_categorical_accuracy: 0.6311 - val_loss: 1.5136 - val_sparse_categorical_accuracy: 0.6360
# Epoch 168/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5226 - sparse_categorical_accuracy: 0.6306 - val_loss: 1.4975 - val_sparse_categorical_accuracy: 0.6387
# Epoch 169/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5192 - sparse_categorical_accuracy: 0.6323 - val_loss: 1.4660 - val_sparse_categorical_accuracy: 0.6528
# Epoch 170/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5133 - sparse_categorical_accuracy: 0.6345 - val_loss: 1.5140 - val_sparse_categorical_accuracy: 0.6354
# Epoch 171/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.5140 - sparse_categorical_accuracy: 0.6339 - val_loss: 1.4715 - val_sparse_categorical_accuracy: 0.6397
# Epoch 172/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5130 - sparse_categorical_accuracy: 0.6332 - val_loss: 1.5394 - val_sparse_categorical_accuracy: 0.6299
# Epoch 173/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5156 - sparse_categorical_accuracy: 0.6374 - val_loss: 1.4514 - val_sparse_categorical_accuracy: 0.6592
# Epoch 174/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.5137 - sparse_categorical_accuracy: 0.6352 - val_loss: 1.4937 - val_sparse_categorical_accuracy: 0.6383
# Epoch 175/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5116 - sparse_categorical_accuracy: 0.6362 - val_loss: 1.5371 - val_sparse_categorical_accuracy: 0.6288
# Epoch 176/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5059 - sparse_categorical_accuracy: 0.6393 - val_loss: 1.5816 - val_sparse_categorical_accuracy: 0.6254
# Epoch 177/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.5067 - sparse_categorical_accuracy: 0.6364 - val_loss: 1.5106 - val_sparse_categorical_accuracy: 0.6388
# Epoch 178/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5088 - sparse_categorical_accuracy: 0.6356 - val_loss: 1.4469 - val_sparse_categorical_accuracy: 0.6612
# Epoch 179/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5169 - sparse_categorical_accuracy: 0.6394 - val_loss: 1.4945 - val_sparse_categorical_accuracy: 0.6419
# Epoch 180/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5085 - sparse_categorical_accuracy: 0.6392 - val_loss: 1.4321 - val_sparse_categorical_accuracy: 0.6652
# Epoch 181/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5048 - sparse_categorical_accuracy: 0.6406 - val_loss: 1.4535 - val_sparse_categorical_accuracy: 0.6530
# Epoch 182/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5062 - sparse_categorical_accuracy: 0.6420 - val_loss: 1.5646 - val_sparse_categorical_accuracy: 0.6255
# Epoch 183/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5026 - sparse_categorical_accuracy: 0.6391 - val_loss: 1.4271 - val_sparse_categorical_accuracy: 0.6646
# Epoch 184/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5049 - sparse_categorical_accuracy: 0.6413 - val_loss: 1.4456 - val_sparse_categorical_accuracy: 0.6617
# Epoch 185/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.4997 - sparse_categorical_accuracy: 0.6438 - val_loss: 1.4872 - val_sparse_categorical_accuracy: 0.6460
# Epoch 186/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.4953 - sparse_categorical_accuracy: 0.6449 - val_loss: 1.5302 - val_sparse_categorical_accuracy: 0.6321
# Epoch 187/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.4964 - sparse_categorical_accuracy: 0.6434 - val_loss: 1.4154 - val_sparse_categorical_accuracy: 0.6695
# Epoch 188/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5010 - sparse_categorical_accuracy: 0.6414 - val_loss: 1.5064 - val_sparse_categorical_accuracy: 0.6485
# Epoch 189/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.4949 - sparse_categorical_accuracy: 0.6455 - val_loss: 1.4570 - val_sparse_categorical_accuracy: 0.6579
# Epoch 190/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.4971 - sparse_categorical_accuracy: 0.6456 - val_loss: 1.4722 - val_sparse_categorical_accuracy: 0.6595
# Epoch 191/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.4963 - sparse_categorical_accuracy: 0.6450 - val_loss: 1.4494 - val_sparse_categorical_accuracy: 0.6702
# Epoch 192/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.4952 - sparse_categorical_accuracy: 0.6481 - val_loss: 1.4545 - val_sparse_categorical_accuracy: 0.6608
# Epoch 193/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.4928 - sparse_categorical_accuracy: 0.6484 - val_loss: 1.4463 - val_sparse_categorical_accuracy: 0.6606
# Epoch 194/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.4912 - sparse_categorical_accuracy: 0.6481 - val_loss: 1.4481 - val_sparse_categorical_accuracy: 0.6584
# Epoch 195/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.4947 - sparse_categorical_accuracy: 0.6473 - val_loss: 1.4420 - val_sparse_categorical_accuracy: 0.6650
# Epoch 196/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.4912 - sparse_categorical_accuracy: 0.6499 - val_loss: 1.4962 - val_sparse_categorical_accuracy: 0.6436
# Epoch 197/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.4926 - sparse_categorical_accuracy: 0.6507 - val_loss: 1.4154 - val_sparse_categorical_accuracy: 0.6717
# Epoch 198/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.4913 - sparse_categorical_accuracy: 0.6516 - val_loss: 1.4656 - val_sparse_categorical_accuracy: 0.6568
# Epoch 199/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.4842 - sparse_categorical_accuracy: 0.6521 - val_loss: 1.4591 - val_sparse_categorical_accuracy: 0.6661
# Epoch 200/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.4968 - sparse_categorical_accuracy: 0.6496 - val_loss: 1.4743 - val_sparse_categorical_accuracy: 0.6478

# %% [markdown]
# Things to try:
# - Change learning rate in SGD
# - Change momentum in SGD
# - Add early stopping callback with long patience?

# %%
def experiment(learning_rate,momentum,run_number):
  start_time = time.time()
  model = get_model()
  model.compile(optimizer=keras.optimizers.SGD(learning_rate=learning_rate,momentum=momentum,clipnorm=1.0),
              loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = [keras.metrics.SparseCategoricalAccuracy()])
  early_stopping = keras.callbacks.EarlyStopping(monitor="val_sparse_categorical_accuracy",patience=20,restore_best_weights=True)
  history = model.fit(train_data_loader, epochs=200, validation_data=val_data_loader,callbacks=[early_stopping])
  model.save(f"/content/drive/MyDrive/deep_learning_cw2/run_{run_number}/run_{run_number}.keras")
  end_time = time.time()
  training_time = end_time - start_time
  print(training_time)
  return history

# %%
history3 = experiment(learning_rate = 0.01, momentum = 0.5, run_number = 3)
# Out:
# Epoch 1/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 100ms/step - loss: 14.9669 - sparse_categorical_accuracy: 0.2484 - val_loss: 12.5122 - val_sparse_categorical_accuracy: 0.3211
# Epoch 2/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 10.7206 - sparse_categorical_accuracy: 0.3334 - val_loss: 9.0824 - val_sparse_categorical_accuracy: 0.3610
# Epoch 3/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 7.9547 - sparse_categorical_accuracy: 0.3573 - val_loss: 6.8070 - val_sparse_categorical_accuracy: 0.4164
# Epoch 4/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 6.1157 - sparse_categorical_accuracy: 0.3693 - val_loss: 5.3564 - val_sparse_categorical_accuracy: 0.4071
# Epoch 5/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss:
# Epoch 86/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6422 - sparse_categorical_accuracy: 0.5748 - val_loss: 1.5731 - val_sparse_categorical_accuracy: 0.5987
# Epoch 87/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6337 - sparse_categorical_accuracy: 0.5780 - val_loss: 1.7341 - val_sparse_categorical_accuracy: 0.5660
# Epoch 88/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6294 - sparse_categorical_accuracy: 0.5791 - val_loss: 1.6645 - val_sparse_categorical_accuracy: 0.5787
# Epoch 89/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6307 - sparse_categorical_accuracy: 0.5816 - val_loss: 1.6832 - val_sparse_categorical_accuracy: 0.5590
# Epoch 90/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6307 - sparse_categorical_accuracy: 0.5813 - val_loss: 1.5891 - val_sparse_categorical_accuracy: 0.6039
# Epoch 91/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.6294 - sparse_categorical_accuracy: 0.5800 - val_loss: 1.5944 - val_sparse_categorical_accuracy: 0.5994
# Epoch 92/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6264 - sparse_categorical_accuracy: 0.5821 - val_loss: 1.7595 - val_sparse_categorical_accuracy: 0.5601
# Epoch 93/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6243 - sparse_categorical_accuracy: 0.5829 - val_loss: 1.6646 - val_sparse_categorical_accuracy: 0.5652
# Epoch 94/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6194 - sparse_categorical_accuracy: 0.5831 - val_loss: 1.5751 - val_sparse_categorical_accuracy: 0.5904
# Epoch 95/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6251 - sparse_categorical_accuracy: 0.5828 - val_loss: 1.5404 - val_sparse_categorical_accuracy: 0.6081
# Epoch 96/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6227 - sparse_categorical_accuracy: 0.5836 - val_loss: 1.6772 - val_sparse_categorical_accuracy: 0.5735
# Epoch 97/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6239 - sparse_categorical_accuracy: 0.5860 - val_loss: 1.5285 - val_sparse_categorical_accuracy: 0.6170
# Epoch 98/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6164 - sparse_categorical_accuracy: 0.5902 - val_loss: 1.6547 - val_sparse_categorical_accuracy: 0.5815
# Epoch 99/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.6283 - sparse_categorical_accuracy: 0.5875 - val_loss: 1.5316 - val_sparse_categorical_accuracy: 0.6193
# Epoch 100/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6278 - sparse_categorical_accuracy: 0.5870 - val_loss: 1.6127 - val_sparse_categorical_accuracy: 0.5925
# Epoch 101/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6183 - sparse_categorical_accuracy: 0.5869 - val_loss: 1.6150 - val_sparse_categorical_accuracy: 0.5911
# Epoch 102/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6090 - sparse_categorical_accuracy: 0.5928 - val_loss: 1.6901 - val_sparse_categorical_accuracy: 0.5665
# Epoch 103/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6114 - sparse_categorical_accuracy: 0.5937 - val_loss: 1.5116 - val_sparse_categorical_accuracy: 0.6244
# Epoch 104/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.6117 - sparse_categorical_accuracy: 0.5934 - val_loss: 1.5795 - val_sparse_categorical_accuracy: 0.6043
# Epoch 105/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6164 - sparse_categorical_accuracy: 0.5910 - val_loss: 1.7379 - val_sparse_categorical_accuracy: 0.5453
# Epoch 106/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6112 - sparse_categorical_accuracy: 0.5936 - val_loss: 1.5600 - val_sparse_categorical_accuracy: 0.6087
# Epoch 107/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6058 - sparse_categorical_accuracy: 0.5959 - val_loss: 1.5969 - val_sparse_categorical_accuracy: 0.5949
# Epoch 108/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6057 - sparse_categorical_accuracy: 0.5974 - val_loss: 1.7475 - val_sparse_categorical_accuracy: 0.5644
# Epoch 109/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6069 - sparse_categorical_accuracy: 0.5946 - val_loss: 1.5448 - val_sparse_categorical_accuracy: 0.6153
# Epoch 110/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5977 - sparse_categorical_accuracy: 0.6022 - val_loss: 1.5922 - val_sparse_categorical_accuracy: 0.6075
# Epoch 111/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6020 - sparse_categorical_accuracy: 0.5996 - val_loss: 1.5770 - val_sparse_categorical_accuracy: 0.6059
# Epoch 112/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5969 - sparse_categorical_accuracy: 0.5982 - val_loss: 1.5132 - val_sparse_categorical_accuracy: 0.6293
# Epoch 113/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6015 - sparse_categorical_accuracy: 0.5991 - val_loss: 1.5262 - val_sparse_categorical_accuracy: 0.6253
# Epoch 114/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.6033 - sparse_categorical_accuracy: 0.6011 - val_loss: 1.5922 - val_sparse_categorical_accuracy: 0.6008
# Epoch 115/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5998 - sparse_categorical_accuracy: 0.5990 - val_loss: 1.5111 - val_sparse_categorical_accuracy: 0.6272
# Epoch 116/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5992 - sparse_categorical_accuracy: 0.6016 - val_loss: 1.5331 - val_sparse_categorical_accuracy: 0.6196
# Epoch 117/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.5928 - sparse_categorical_accuracy: 0.6030 - val_loss: 1.5403 - val_sparse_categorical_accuracy: 0.6171
# Epoch 118/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5945 - sparse_categorical_accuracy: 0.6026 - val_loss: 1.5009 - val_sparse_categorical_accuracy: 0.6346
# Epoch 119/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6010 - sparse_categorical_accuracy: 0.6030 - val_loss: 1.6746 - val_sparse_categorical_accuracy: 0.5862
# Epoch 120/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5991 - sparse_categorical_accuracy: 0.6023 - val_loss: 1.4925 - val_sparse_categorical_accuracy: 0.6317
# Epoch 121/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6019 - sparse_categorical_accuracy: 0.6002 - val_loss: 1.5405 - val_sparse_categorical_accuracy: 0.6243
# Epoch 122/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5951 - sparse_categorical_accuracy: 0.6066 - val_loss: 1.4969 - val_sparse_categorical_accuracy: 0.6366
# Epoch 123/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5953 - sparse_categorical_accuracy: 0.6024 - val_loss: 1.5217 - val_sparse_categorical_accuracy: 0.6221
# Epoch 124/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5898 - sparse_categorical_accuracy: 0.6091 - val_loss: 1.5185 - val_sparse_categorical_accuracy: 0.6233
# Epoch 125/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.5932 - sparse_categorical_accuracy: 0.6053 - val_loss: 1.7066 - val_sparse_categorical_accuracy: 0.5675
# Epoch 126/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5834 - sparse_categorical_accuracy: 0.6104 - val_loss: 1.5177 - val_sparse_categorical_accuracy: 0.6317
# Epoch 127/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5915 - sparse_categorical_accuracy: 0.6075 - val_loss: 1.5330 - val_sparse_categorical_accuracy: 0.6332
# Epoch 128/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5858 - sparse_categorical_accuracy: 0.6086 - val_loss: 1.6162 - val_sparse_categorical_accuracy: 0.5963
# Epoch 129/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 102ms/step - loss: 1.5812 - sparse_categorical_accuracy: 0.6134 - val_loss: 1.5063 - val_sparse_categorical_accuracy: 0.6359
# Epoch 130/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5843 - sparse_categorical_accuracy: 0.6115 - val_loss: 1.5154 - val_sparse_categorical_accuracy: 0.6265
# Epoch 131/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5813 - sparse_categorical_accuracy: 0.6101 - val_loss: 1.5764 - val_sparse_categorical_accuracy: 0.6078
# Epoch 132/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5783 - sparse_categorical_accuracy: 0.6116 - val_loss: 1.5425 - val_sparse_categorical_accuracy: 0.6248
# Epoch 133/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5793 - sparse_categorical_accuracy: 0.6110 - val_loss: 1.5580 - val_sparse_categorical_accuracy: 0.6203
# Epoch 134/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5804 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.6051 - val_sparse_categorical_accuracy: 0.6050
# Epoch 135/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5803 - sparse_categorical_accuracy: 0.6130 - val_loss: 1.5603 - val_sparse_categorical_accuracy: 0.6166
# Epoch 136/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5796 - sparse_categorical_accuracy: 0.6110 - val_loss: 1.6498 - val_sparse_categorical_accuracy: 0.5894
# Epoch 137/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5774 - sparse_categorical_accuracy: 0.6159 - val_loss: 1.5079 - val_sparse_categorical_accuracy: 0.6348
# Epoch 138/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.5726 - sparse_categorical_accuracy: 0.6141 - val_loss: 1.5154 - val_sparse_categorical_accuracy: 0.6314
# Epoch 139/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5761 - sparse_categorical_accuracy: 0.6155 - val_loss: 1.7993 - val_sparse_categorical_accuracy: 0.5652
# Epoch 140/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5713 - sparse_categorical_accuracy: 0.6169 - val_loss: 1.4921 - val_sparse_categorical_accuracy: 0.6386
# Epoch 141/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5722 - sparse_categorical_accuracy: 0.6176 - val_loss: 1.5597 - val_sparse_categorical_accuracy: 0.6161
# Epoch 142/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5736 - sparse_categorical_accuracy: 0.6201 - val_loss: 1.5695 - val_sparse_categorical_accuracy: 0.6080
# Epoch 143/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5751 - sparse_categorical_accuracy: 0.6191 - val_loss: 1.4827 - val_sparse_categorical_accuracy: 0.6525
# Epoch 144/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5758 - sparse_categorical_accuracy: 0.6166 - val_loss: 1.6716 - val_sparse_categorical_accuracy: 0.5924
# Epoch 145/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5699 - sparse_categorical_accuracy: 0.6209 - val_loss: 1.5181 - val_sparse_categorical_accuracy: 0.6387
# Epoch 146/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5652 - sparse_categorical_accuracy: 0.6226 - val_loss: 1.5115 - val_sparse_categorical_accuracy: 0.6439
# Epoch 147/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.5711 - sparse_categorical_accuracy: 0.6222 - val_loss: 1.4875 - val_sparse_categorical_accuracy: 0.6504
# Epoch 148/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5793 - sparse_categorical_accuracy: 0.6155 - val_loss: 1.5499 - val_sparse_categorical_accuracy: 0.6199
# Epoch 149/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5716 - sparse_categorical_accuracy: 0.6208 - val_loss: 1.5507 - val_sparse_categorical_accuracy: 0.6281
# Epoch 150/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5668 - sparse_categorical_accuracy: 0.6237 - val_loss: 1.5362 - val_sparse_categorical_accuracy: 0.6351
# Epoch 151/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5710 - sparse_categorical_accuracy: 0.6220 - val_loss: 1.5295 - val_sparse_categorical_accuracy: 0.6372
# Epoch 152/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5692 - sparse_categorical_accuracy: 0.6257 - val_loss: 1.7756 - val_sparse_categorical_accuracy: 0.5688
# Epoch 153/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5657 - sparse_categorical_accuracy: 0.6250 - val_loss: 1.5409 - val_sparse_categorical_accuracy: 0.6259
# Epoch 154/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5687 - sparse_categorical_accuracy: 0.6219 - val_loss: 1.4835 - val_sparse_categorical_accuracy: 0.6495
# Epoch 155/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5643 - sparse_categorical_accuracy: 0.6252 - val_loss: 1.4700 - val_sparse_categorical_accuracy: 0.6536
# Epoch 156/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5606 - sparse_categorical_accuracy: 0.6280 - val_loss: 1.5776 - val_sparse_categorical_accuracy: 0.6189
# Epoch 157/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5665 - sparse_categorical_accuracy: 0.6251 - val_loss: 1.5046 - val_sparse_categorical_accuracy: 0.6434
# Epoch 158/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5785 - sparse_categorical_accuracy: 0.6224 - val_loss: 1.5840 - val_sparse_categorical_accuracy: 0.6215
# Epoch 159/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5603 - sparse_categorical_accuracy: 0.6269 - val_loss: 1.6350 - val_sparse_categorical_accuracy: 0.6055
# Epoch 160/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5647 - sparse_categorical_accuracy: 0.6281 - val_loss: 1.4689 - val_sparse_categorical_accuracy: 0.6522
# Epoch 161/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5582 - sparse_categorical_accuracy: 0.6280 - val_loss: 1.4770 - val_sparse_categorical_accuracy: 0.6527
# Epoch 162/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5618 - sparse_categorical_accuracy: 0.6288 - val_loss: 1.5334 - val_sparse_categorical_accuracy: 0.6373
# Epoch 163/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5572 - sparse_categorical_accuracy: 0.6260 - val_loss: 1.5824 - val_sparse_categorical_accuracy: 0.6212
# Epoch 164/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5612 - sparse_categorical_accuracy: 0.6269 - val_loss: 1.4891 - val_sparse_categorical_accuracy: 0.6546
# Epoch 165/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5666 - sparse_categorical_accuracy: 0.6292 - val_loss: 1.5256 - val_sparse_categorical_accuracy: 0.6464
# Epoch 166/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5589 - sparse_categorical_accuracy: 0.6287 - val_loss: 1.5650 - val_sparse_categorical_accuracy: 0.6207
# Epoch 167/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5609 - sparse_categorical_accuracy: 0.6302 - val_loss: 1.5855 - val_sparse_categorical_accuracy: 0.6158
# Epoch 168/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5621 - sparse_categorical_accuracy: 0.6291 - val_loss: 1.5790 - val_sparse_categorical_accuracy: 0.6119
# Epoch 169/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.5639 - sparse_categorical_accuracy: 0.6288 - val_loss: 1.4854 - val_sparse_categorical_accuracy: 0.6530
# Epoch 170/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.5635 - sparse_categorical_accuracy: 0.6301 - val_loss: 1.5394 - val_sparse_categorical_accuracy: 0.6353
# Epoch 171/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5673 - sparse_categorical_accuracy: 0.6281 - val_loss: 1.5306 - val_sparse_categorical_accuracy: 0.6437
# Epoch 172/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5722 - sparse_categorical_accuracy: 0.6294 - val_loss: 1.4946 - val_sparse_categorical_accuracy: 0.6524
# Epoch 173/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5721 - sparse_categorical_accuracy: 0.6286 - val_loss: 1.8751 - val_sparse_categorical_accuracy: 0.5516
# Epoch 174/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5613 - sparse_categorical_accuracy: 0.6323 - val_loss: 1.5502 - val_sparse_categorical_accuracy: 0.6310
# Epoch 175/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5689 - sparse_categorical_accuracy: 0.6317 - val_loss: 1.5369 - val_sparse_categorical_accuracy: 0.6453
# Epoch 176/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5624 - sparse_categorical_accuracy: 0.6332 - val_loss: 1.5511 - val_sparse_categorical_accuracy: 0.6281
# Epoch 177/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5617 - sparse_categorical_accuracy: 0.6320 - val_loss: 1.5768 - val_sparse_categorical_accuracy: 0.6327
# Epoch 178/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5594 - sparse_categorical_accuracy: 0.6339 - val_loss: 1.4796 - val_sparse_categorical_accuracy: 0.6633
# Epoch 179/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5628 - sparse_categorical_accuracy: 0.6357 - val_loss: 1.5199 - val_sparse_categorical_accuracy: 0.6484
# Epoch 180/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5490 - sparse_categorical_accuracy: 0.6386 - val_loss: 1.5973 - val_sparse_categorical_accuracy: 0.6240
# Epoch 181/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5502 - sparse_categorical_accuracy: 0.6389 - val_loss: 1.6481 - val_sparse_categorical_accuracy: 0.6105
# Epoch 182/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5508 - sparse_categorical_accuracy: 0.6414 - val_loss: 1.5979 - val_sparse_categorical_accuracy: 0.6270
# Epoch 183/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5444 - sparse_categorical_accuracy: 0.6402 - val_loss: 1.4663 - val_sparse_categorical_accuracy: 0.6654
# Epoch 184/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5496 - sparse_categorical_accuracy: 0.6396 - val_loss: 1.5006 - val_sparse_categorical_accuracy: 0.6479
# Epoch 185/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.5521 - sparse_categorical_accuracy: 0.6370 - val_loss: 1.4748 - val_sparse_categorical_accuracy: 0.6601
# Epoch 186/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5487 - sparse_categorical_accuracy: 0.6392 - val_loss: 1.5635 - val_sparse_categorical_accuracy: 0.6370
# Epoch 187/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5529 - sparse_categorical_accuracy: 0.6390 - val_loss: 1.5521 - val_sparse_categorical_accuracy: 0.6347
# Epoch 188/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5558 - sparse_categorical_accuracy: 0.6372 - val_loss: 1.5532 - val_sparse_categorical_accuracy: 0.6325
# Epoch 189/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5461 - sparse_categorical_accuracy: 0.6410 - val_loss: 1.4525 - val_sparse_categorical_accuracy: 0.6657
# Epoch 190/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5403 - sparse_categorical_accuracy: 0.6421 - val_loss: 1.5097 - val_sparse_categorical_accuracy: 0.6472
# Epoch 191/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5507 - sparse_categorical_accuracy: 0.6382 - val_loss: 1.7229 - val_sparse_categorical_accuracy: 0.6128
# Epoch 192/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5514 - sparse_categorical_accuracy: 0.6408 - val_loss: 1.4801 - val_sparse_categorical_accuracy: 0.6697
# Epoch 193/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5419 - sparse_categorical_accuracy: 0.6442 - val_loss: 1.4908 - val_sparse_categorical_accuracy: 0.6592
# Epoch 194/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5382 - sparse_categorical_accuracy: 0.6448 - val_loss: 1.4523 - val_sparse_categorical_accuracy: 0.6667
# Epoch 195/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5339 - sparse_categorical_accuracy: 0.6423 - val_loss: 1.4457 - val_sparse_categorical_accuracy: 0.6729
# Epoch 196/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5372 - sparse_categorical_accuracy: 0.6424 - val_loss: 1.6118 - val_sparse_categorical_accuracy: 0.6020
# Epoch 197/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5307 - sparse_categorical_accuracy: 0.6467 - val_loss: 1.4892 - val_sparse_categorical_accuracy: 0.6539
# Epoch 198/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.5376 - sparse_categorical_accuracy: 0.6428 - val_loss: 1.4915 - val_sparse_categorical_accuracy: 0.6658
# Epoch 199/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.5322 - sparse_categorical_accuracy: 0.6460 - val_loss: 1.5555 - val_sparse_categorical_accuracy: 0.6346
# Epoch 200/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.5285 - sparse_categorical_accuracy: 0.6477 - val_loss: 1.5806 - val_sparse_categorical_accuracy: 0.6218
# 12587.711283922195

# %%
history4 = experiment(learning_rate = 0.01, momentum = 0.9, run_number = 4)

# %%
history5 = experiment(learning_rate=0.02, momentum=0.5, run_number = 5)
# Out:
# Epoch 1/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 102ms/step - loss: 12.3525 - sparse_categorical_accuracy: 0.2474 - val_loss: 8.1635 - val_sparse_categorical_accuracy: 0.3054
# Epoch 2/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss:
200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.6001 - sparse_categorical_accuracy: 0.6183 - val_loss: 1.6136 - val_sparse_categorical_accuracy: 0.6098
# Epoch 121/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.6033 - sparse_categorical_accuracy: 0.6201 - val_loss: 1.6920 - val_sparse_categorical_accuracy: 0.5996
# Epoch 122/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5983 - sparse_categorical_accuracy: 0.6213 - val_loss: 1.6236 - val_sparse_categorical_accuracy: 0.6152
# Epoch 123/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.6001 - sparse_categorical_accuracy: 0.6209 - val_loss: 1.6415 - val_sparse_categorical_accuracy: 0.6191
# Epoch 124/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5921 - sparse_categorical_accuracy: 0.6218 - val_loss: 1.5786 - val_sparse_categorical_accuracy: 0.6280
# Epoch 125/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5940 - sparse_categorical_accuracy: 0.6235 - val_loss: 1.5050 - val_sparse_categorical_accuracy: 0.6520
# Epoch 126/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5977 - sparse_categorical_accuracy: 0.6221 - val_loss: 1.6481 - val_sparse_categorical_accuracy: 0.5945
# Epoch 127/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 103ms/step - loss: 1.5911 - sparse_categorical_accuracy: 0.6272 - val_loss: 1.5998 - val_sparse_categorical_accuracy: 0.6137
# Epoch 128/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - loss: 1.5975 - sparse_categorical_accuracy: 0.6256 - val_loss: 1.5503 - val_sparse_categorical_accuracy: 0.6392
# Epoch 129/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.5964 - sparse_categorical_accuracy: 0.6239 - val_loss: 1.5108 - val_sparse_categorical_accuracy: 0.6560
# Epoch 130/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5960 - sparse_categorical_accuracy: 0.6268 - val_loss: 1.7461 - val_sparse_categorical_accuracy: 0.5756
# Epoch 131/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.6018 - sparse_categorical_accuracy: 0.6239 - val_loss: 1.4938 - val_sparse_categorical_accuracy: 0.6633
# Epoch 132/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.6006 - sparse_categorical_accuracy: 0.6254 - val_loss: 1.6928 - val_sparse_categorical_accuracy: 0.6022
# Epoch 133/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5966 - sparse_categorical_accuracy: 0.6274 - val_loss: 1.5100 - val_sparse_categorical_accuracy: 0.6569
# Epoch 134/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.6018 - sparse_categorical_accuracy: 0.6248 - val_loss: 1.5156 - val_sparse_categorical_accuracy: 0.6563
# Epoch 135/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5962 - sparse_categorical_accuracy: 0.6273 - val_loss: 1.5001 - val_sparse_categorical_accuracy: 0.6606
# Epoch 136/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5992 - sparse_categorical_accuracy: 0.6276 - val_loss: 1.5737 - val_sparse_categorical_accuracy: 0.6349
# Epoch 137/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5966 - sparse_categorical_accuracy: 0.6272 - val_loss: 1.5794 - val_sparse_categorical_accuracy: 0.6299
# Epoch 138/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5990 - sparse_categorical_accuracy: 0.6261 - val_loss: 1.5406 - val_sparse_categorical_accuracy: 0.6543
# Epoch 139/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5993 - sparse_categorical_accuracy: 0.6276 - val_loss: 1.5417 - val_sparse_categorical_accuracy: 0.6467
# Epoch 140/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.6052 - sparse_categorical_accuracy: 0.6271 - val_loss: 1.5301 - val_sparse_categorical_accuracy: 0.6513
# Epoch 141/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1.6037 - sparse_categorical_accuracy: 0.6269 - val_loss: 1.6667 - val_sparse_categorical_accuracy: 0.6120
# Epoch 142/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.6024 - sparse_categorical_accuracy: 0.6287 - val_loss: 1.6640 - val_sparse_categorical_accuracy: 0.6035
# Epoch 143/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 1
# Epoch 72/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.7472 - sparse_categorical_accuracy: 0.5252 - val_loss: 1.7231 - val_sparse_categorical_accuracy: 0.5325
# 4625.072418451309

# %%
def experiment2(learning_rate,momentum,run_number):
  start_time = time.time()
  model = get_model()
  model.compile(optimizer=keras.optimizers.SGD(learning_rate=learning_rate,momentum=momentum,clipnorm=1.0,nesterov=True),
              loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = [keras.metrics.SparseCategoricalAccuracy()])
  early_stopping = keras.callbacks.EarlyStopping(monitor="val_sparse_categorical_accuracy",patience=20,restore_best_weights=True)
  history = model.fit(train_data_loader, epochs=200, validation_data=val_data_loader,callbacks=[early_stopping])
  model.save(f"/content/drive/MyDrive/deep_learning_cw2/run_{run_number}/run_{run_number}.keras")
  end_time = time.time()
  training_time = end_time - start_time
  print(training_time)
  return history

# %%
history9 = experiment2(learning_rate = 0.01,momentum=0.5,run_number=9)
# Out:
# Epoch 1/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 14.7827 - sparse_categorical_accuracy: 0.2304 - val_loss: 12.1593 - val_sparse_categorical_accuracy: 0.2918
# Epoch 2/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 10.4015 - sparse_categorical_accuracy: 0.3094 - val_loss: 8.7483 - val_sparse_categorical_accuracy: 0.3372
# Epoch 3/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 7.6126 - sparse_categorical_accuracy: 0.3366 - val_loss: 6.4667 - val_sparse_categorical_accuracy: 0.3631
# Epoch 4/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 5.7578 - sparse_categorical_accuracy: 0.3531 - val_loss: 4.9940 - val_sparse_categorical_accuracy: 0.3722
# Epoch 5/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 4.5210 - sparse_categorical_accuracy: 0.3652 - val_loss: 3.9470 - val_sparse_categorical_accuracy: 0.4055
# Epoch 6/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 3.6886 - sparse_categorical_accuracy: 0.3771 - val_loss: 3.2775 - val_sparse_categorical_accuracy: 0.4023
# Epoch 7/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 3.1216 - sparse_categorical_accuracy: 0.3832 - val_loss: 2.7864 - val_sparse_categorical_accuracy: 0.4266
# Epoch 8/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 2.7465 - sparse_categorical_accuracy: 0.3849 - val_loss: 2.5835 - val_sparse_categorical_accuracy: 0.4175
# Epoch 9/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 2.4878 - sparse_categorical_accuracy: 0.3906 - val_loss: 2.3172 - val_sparse_categorical_accuracy: 0.4203
# Epoch 10/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 2.3122 - sparse_categorical_accuracy: 0.3938 - val_loss: 2.1884 - val_sparse_categorical_accuracy: 0.4193
# Epoch 11/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 2.1914 - sparse_categorical_accuracy: 0.3969 - val_loss: 2.0129 - val_sparse_categorical_accuracy: 0.4488
# Epoch 12/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 2.1044 - sparse_categorical_accuracy: 0.3997 - val_loss: 1.9703 - val_sparse_categorical_accuracy: 0.4328
# Epoch 13/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 2.0359 - sparse_categorical_accuracy: 0.4042 - val_loss: 1.9477 - val_sparse_categorical_accuracy: 0.4275
# Epoch 14/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.9892 - sparse_categorical_accuracy: 0.4063 - val_loss: 1.8891 - val_sparse_categorical_accuracy: 0.4338
# Epoch 15/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.9520 - sparse_categorical_accuracy: 0.4141 - val_loss: 1.8524 - val_sparse_categorical_accuracy: 0.4298
# Epoch 16/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.9298 - sparse_categorical_accuracy: 0.4150 - val_loss: 1.8066 - val_sparse_categorical_accuracy: 0.4449
# Epoch 17/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.9082 - sparse_categorical_accuracy: 0.4178 - val_loss: 1.8435 - val_sparse_categorical_accuracy: 0.4458
# Epoch 18/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.8894 - sparse_categorical_accuracy: 0.4205 - val_loss: 1.7679 - val_sparse_categorical_accuracy: 0.4647
# Epoch 19/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.8790 - sparse_categorical_accuracy: 0.4219 - val_loss: 1.7415 - val_sparse_categorical_accuracy: 0.4736
# Epoch 20/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.
200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6978 - sparse_categorical_accuracy: 0.5593 - val_loss: 1.6828 - val_sparse_categorical_accuracy: 0.5730
# Epoch 103/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.7002 - sparse_categorical_accuracy: 0.5592 - val_loss: 1.6467 - val_sparse_categorical_accuracy: 0.5865
# Epoch 104/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.6914 - sparse_categorical_accuracy: 0.5653 - val_loss: 1.6084 - val_sparse_categorical_accuracy: 0.5825
# Epoch 105/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.6985 - sparse_categorical_accuracy: 0.5630 - val_loss: 1.6227 - val_sparse_categorical_accuracy: 0.5886
# Epoch 106/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.6985 - sparse_categorical_accuracy: 0.5645 - val_loss: 1.6539 - val_sparse_categorical_accuracy: 0.5791
# Epoch 107/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.7017 - sparse_categorical_accuracy: 0.5665 - val_loss: 1.6767 - val_sparse_categorical_accuracy: 0.5685
# Epoch 108/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.7051 - sparse_categorical_accuracy: 0.5623 - val_loss: 1.6486 - val_sparse_categorical_accuracy: 0.5841
# Epoch 109/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.7045 - sparse_categorical_accuracy: 0.5655 - val_loss: 1.5731 - val_sparse_categorical_accuracy: 0.6083
# Epoch 110/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.6994 - sparse_categorical_accuracy: 0.5666 - val_loss: 1.6479 - val_sparse_categorical_accuracy: 0.5851
# Epoch 111/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.6990 - sparse_categorical_accuracy: 0.5680 - val_loss: 1.5942 - val_sparse_categorical_accuracy: 0.6081
# Epoch 112/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.7061 - sparse_categorical_accuracy: 0.5633 - val_loss: 1.6557 - val_sparse_categorical_accuracy: 0.5740
# Epoch 113/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.7043 - sparse_categorical_accuracy: 0.5645 - val_loss: 1.6238 - val_sparse_categorical_accuracy: 0.5942
# Epoch 114/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.7212 - sparse_categorical_accuracy: 0.5631 - val_loss: 1.7136 - val_sparse_categorical_accuracy: 0.5568
# Epoch 115/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.7229 - sparse_categorical_accuracy: 0.5639 - val_loss: 1.6218 - val_sparse_categorical_accuracy: 0.6080
# Epoch 116/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.7291 - sparse_categorical_accuracy: 0.5635 - val_loss: 1.6331 - val_sparse_categorical_accuracy: 0.5934
# Epoch 117/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.7374 - sparse_categorical_accuracy: 0.5605 - val_loss: 1.7068 - val_sparse_categorical_accuracy: 0.5711
# Epoch 118/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.7329 - sparse_categorical_accuracy: 0.5646 - val_loss: 1.7021 - val_sparse_categorical_accuracy: 0.5691
# Epoch 119/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.7359 - sparse_categorical_accuracy: 0.5660 - val_loss: 1.6416 - val_sparse_categorical_accuracy: 0.6014
# Epoch 120/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.7311 - sparse_categorical_accuracy: 0.5678 - val_loss: 1.6680 - val_sparse_categorical_accuracy: 0.5776
# Epoch 121/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.7448 - sparse_categorical_accuracy: 0.5631 - val_loss: 1.6938 - val_sparse_categorical_accuracy: 0.5847
# Epoch 122/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.7460 - sparse_categorical_accuracy: 0.5644 - val_loss: 1.6340 - val_sparse_categorical_accuracy: 0.6040
# Epoch 123/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.7432 - sparse_categorical_accuracy: 0.5651 - val_loss: 1.8048 - val_sparse_categorical_accuracy: 0.5339
# Epoch 124/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.7605 - sparse_categorical_accuracy: 0.5634 - val_loss: 1.7145 - val_sparse_categorical_accuracy: 0.5705
# Epoch 125/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1.7574 - sparse_categorical_accuracy: 0.5612 - val_loss: 1.9412 - val_sparse_categorical_accuracy: 0.5267
# Epoch 126/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 1
# Epoch 48/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 2.3841 - sparse_categorical_accuracy: 0.3893 - val_loss: 2.3821 - val_sparse_categorical_accuracy: 0.3826
# Epoch 49/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 2.4788 - sparse_categorical_accuracy: 0.3644 - val_loss: 2.3525 - val_sparse_categorical_accuracy: 0.3910
# Epoch 50/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 2.4698 - sparse_categorical_accuracy: 0.3567 - val_loss: 2.9707 - val_sparse_categorical_accuracy: 0.3182
# Epoch 51/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 2.5495 - sparse_categorical_accuracy: 0.3220 - val_loss: 2.1797 - val_sparse_categorical_accuracy: 0.4203
# Epoch 52/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 103ms/step - loss: 2.4473 - sparse_categorical_accuracy: 0.3428 - val_loss: 2.3127 - val_sparse_categorical_accuracy: 0.4050
# Epoch 53/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 2.4198 - sparse_categorical_accuracy: 0.3490 - val_loss: 2.1651 - val_sparse_categorical_accuracy: 0.4242
# Epoch 54/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 2.3880 - sparse_categorical_accuracy: 0.3550 - val_loss: 2.3812 - val_sparse_categorical_accuracy: 0.3365
# Epoch 55/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 99ms/step - loss: 2.4222 - sparse_categorical_accuracy: 0.3553 - val_loss: 2.0866 - val_sparse_categorical_accuracy: 0.4484
# Epoch 56/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 2.3680 - sparse_categorical_accuracy: 0.3619 - val_loss: 2.1663 - val_sparse_categorical_accuracy: 0.4326
# Epoch 57/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 2.3596 - sparse_categorical_accuracy: 0.3591 - val_loss: 2.1714 - val_sparse_categorical_accuracy: 0.4008
# 3602.6609485149384

# %% [markdown]
# Experiment Results with Cosine Decay Learning Rate:
#
# Initial Learning Rate = 0.01, Momentum = 0.9: 0.6047 after 193 epochs
#
# Initial Learning Rate = 0.01, Momentum = 0.5: 0.6229 after 194 epochs (run2 in folder)
#
# Initial Learning Rate = 0.01, Momentum = 0.2: 0.5945 after 191 epochs (run1 in folder)

# %% [markdown]
# Experiment Results without Cosine Decay Learning Rate:
#
# Learning Rate = 0.01, Momentum = 0.2: 0.6717 after 197 epochs
#
# Learning Rate = 0.01, Momentum = 0.5: 0.6729 after 196 epochs (run 3 in folder)
#
# Learning Rate = 0.01, Momentum = 0.9: (run 4 in folder)

# %% [markdown]
# Learning Rate = 0.02, Momentum = 0.9:
#
# Learning Rate = 0.02, Momentum = 0.5:

# %% [markdown]
# Learning Rate = 0.005, Momentum = 0.9:
#
# Learning Rate = 0.005, Momentum = 0.5:

# %% [markdown]
# Back to batch size = 128:
#
# Learning Rate = 0.2, Momentum = 0.8

# %% [markdown]
# Try increasing the learning rate to 0.03 or 0.05, but not to 0.1

# %%
model2 = keras.saving.load_model('/content/drive/MyDrive/deep_learning_cw2/run_3/run_3.keras',
                        custom_objects={"ResidualBlock": ResidualBlock})

# %%
model2.evaluate(test_data_loader)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 1.4545 - sparse_categorical_accuracy: 0.6740
# [1.4545007944107056, 0.6740000247955322]

# %% [markdown]
# d) Define a second model on the CIFAR-10 dataset. This model should be the same as the model defined in part b), except an additional dropout layer should be included in between the two convolutional layers in every residual block. The model should be defined such that the stochastic dropout mechanism is active at test time as well as at training time. Therefore the model will be a Bayesian neural network implementation, that uses the MC Dropout technique to approximate the posterior distribution.
#
# Aside from the additional dropout layers, the model architecture should be identical to the model in part b).
#
# Print the model summary, and train the model with the same training settings you used in part c).
#
# Compute and print out the final evaluation of your model on the test set (using a single MC sample for each data example).
#
# _Make sure to save your trained model, as it will be used in later questions in this assessment._
#
# **(3 marks)**

# %%
@keras.saving.register_keras_serializable(package="MyLayers")
class MCResidualBlock(keras.layers.Layer):

  def __init__(self,filters,stride,dropout_rate,extra_conv=False,**kwargs):
    super().__init__(**kwargs)
    self.filters = filters
    self.stride = stride
    self.extra_conv = extra_conv
    self.dropout_rate = dropout_rate

  # get_config method necessary for saving and loading model properly
  def get_config(self):
    config = super().get_config()
    config.update(
        {
            "filters": self.filters,
            "stride": self.stride,
            "extra_conv": self.extra_conv,
            "dropout_rate": self.dropout_rate,
        }
      )
    return config

  def build(self):
    self.conv1 = keras.layers.Conv2D(filters=self.filters,kernel_size=3,
                                     strides=self.stride,padding="same",
                                     kernel_regularizer=regularizers.L2(),
                                     kernel_initializer="he_normal")
    self.relu1 = keras.layers.ReLU()
    self.dropout = keras.layers.Dropout(rate=self.dropout_rate)
    self.conv2 = keras.layers.Conv2D(filters=self.filters,kernel_size=3,
                                     strides=1,padding="same",
                                     kernel_regularizer=regularizers.L2(),
                                     kernel_initializer="he_normal")
    if self.extra_conv == True:
      self.conv3 = keras.layers.Conv2D(filters=self.filters,kernel_size=1,
                                       strides=self.stride,padding="valid",
                                       kernel_regularizer=regularizers.L2(),
                                       kernel_initializer="he_normal")

    self.relu2 = keras.layers.ReLU()

  def call(self,inputs):
    x = self.conv1(inputs)
    x = self.relu1(x)
    # Explicitly set dropout to be active even during test time
    x = self.dropout(x, training=True)
    x = self.conv2(x)
    if self.extra_conv:
      x = x + self.conv3(inputs)
    else:
      x = x + inputs
    x = self.relu2(x)
    return x

# %%
def get_MC_model(dropout_rate):
  model = keras.Sequential([keras.layers.Input(shape=(32,32,3)),
                            keras.layers.Conv2D(filters=16,kernel_size=3,
                                    strides=1,padding="same",
                                    kernel_regularizer=regularizers.L2(),
                                    kernel_initializer="he_normal"),
                          keras.layers.ReLU(),
                          MCResidualBlock(filters=16,stride=1,dropout_rate=dropout_rate),
                          MCResidualBlock(filters=16,stride=1,dropout_rate=dropout_rate),
                          MCResidualBlock(filters=16,stride=1,dropout_rate=dropout_rate),
                          MCResidualBlock(filters=32,stride=2,dropout_rate=dropout_rate,extra_conv=True),
                          MCResidualBlock(filters=32,stride=1,dropout_rate=dropout_rate),
                          MCResidualBlock(filters=32,stride=1,dropout_rate=dropout_rate),
                          MCResidualBlock(filters=64,stride=2,dropout_rate=dropout_rate,extra_conv=True),
                          MCResidualBlock(filters=64,stride=1,dropout_rate=dropout_rate),
                          MCResidualBlock(filters=64,stride=1,dropout_rate=dropout_rate),
                          keras.layers.GlobalAveragePooling2D(),
                          keras.layers.Dense(10,kernel_initializer="he_normal")

  ])
  return model

# %% [markdown]
# Experiment with changing rate of dropout:

# %%
def experiment2(dropout_rate,run_number):
  start_time = time.time()
  model = get_MC_model(dropout_rate=dropout_rate)
  model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.01,momentum=0.5,clipnorm=1.0),
              loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = [keras.metrics.SparseCategoricalAccuracy()])
  early_stopping = keras.callbacks.EarlyStopping(monitor="val_sparse_categorical_accuracy",patience=20,restore_best_weights=True)
  history = model.fit(train_data_loader, epochs=200, validation_data=val_data_loader,callbacks=[early_stopping])
  model.save(f"/content/drive/MyDrive/deep_learning_cw2/mc_model_run_{run_number}/run_{run_number}.keras")
  end_time = time.time()
  training_time = end_time - start_time
  print(training_time)
  return history

# %%
history_11 = experiment2(dropout_rate=0.1,run_number=1)
# Out:
# Epoch 1/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 14.8976 - sparse_categorical_accuracy: 0.2386 - val_loss: 12.0697 - val_sparse_categorical_accuracy: 0.3213
# Epoch 2/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 10.2879 - sparse_categorical_accuracy: 0.3196 - val_loss: 8.6839 - val_sparse_categorical_accuracy: 0.3481
# Epoch 3/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 7.5160 - sparse_categorical_accuracy: 0.3507 - val_loss: 6.4572 - val_sparse_categorical_accuracy: 0.3817
# Epoch 4/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 5.7140 - sparse_categorical_accuracy: 0.3624 - val_loss: 4.9553 - val_sparse_categorical_accuracy: 0.3993
# Epoch 5/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 4.5274 - sparse_categorical_accuracy: 0.3671 - val_loss: 3.9575 - val_sparse_categorical_accuracy: 0.4187
# Epoch 6/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 3.7072 - sparse_categorical_accuracy: 0.3719 - val_loss: 3.4408 - val_sparse_categorical_accuracy: 0.3630
# Epoch 7/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 3.1525 - sparse_categorical_accuracy: 0.3801 - val_loss: 2.8675 - val_sparse_categorical_accuracy: 0.4171
# Epoch 8/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 2.7848 - sparse_categorical_accuracy: 0.3804 - val_loss: 2.5612 - val_sparse_categorical_accuracy: 0.4096
# Epoch 9/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 2.5179 - sparse_categorical_accuracy: 0.3860 - val_loss: 2.3264 - val_sparse_categorical_accuracy: 0.4237
# Epoch 10/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 2.3429 - sparse_categorical_accuracy: 0.3907 - val_loss: 2.2317 - val_sparse_categorical_accuracy: 0.4086
# Epoch 11/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 2.2167 - sparse_categorical_accuracy: 0.3931 - val_loss: 2.0937 - val_sparse_categorical_accuracy: 0.4106
# Epoch 12/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 2.1283 - sparse_categorical_accuracy: 0.3959 - val_loss: 1.9603 - val_sparse_categorical_accuracy: 0.4386
# Epoch 13/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 2.0511 - sparse_categorical_accuracy: 0.3998 - val_loss: 1.9535 - val_sparse_categorical_accuracy: 0.4314
# Epoch 14/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 2.0098 - sparse_categorical_accuracy: 0.4016 - val_loss: 1.9922 - val_sparse_categorical_accuracy: 0.4086
# Epoch 15/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.9754 - sparse_categorical_accuracy: 0.4022 - val_loss: 1.8350 - val_sparse_categorical_accuracy: 0.4481
# Epoch 16/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.9429 - sparse_categorical_accuracy: 0.4038 - val_loss: 1.8130 - val_sparse_categorical_accuracy: 0.4580
# Epoch 17/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.9253 - sparse_categorical_accuracy: 0.4086 - val_loss: 1.8754 - val_sparse_categorical_accuracy: 0.4227
# Epoch 18/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.9083 - sparse_categorical_accuracy: 0.4112 - val_loss: 1.8289 - val_sparse_categorical_accuracy: 0.4256
# Epoch 19/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.8939 - sparse_categorical_accuracy: 0.4128 - val_loss: 1.7752 - val_sparse_categorical_accuracy: 0.4604
# Epoch 20/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.8831 - sparse_categorical_accuracy: 0.4164 - val_loss: 1.7951 - val_sparse_categorical_accuracy: 0.4410
# Epoch 21/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.8688 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.8713 - val_sparse_categorical_accuracy: 0.4099
# Epoch 22/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.8549 - sparse_categorical_accuracy: 0.4241 - val_loss: 1.7996 - val_sparse_categorical_accuracy: 0.4500
# Epoch 23/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.8468 - sparse_categorical_accuracy: 0.4236 - val_loss: 1.8259 - val_sparse_categorical_accuracy: 0.4472
# Epoch 24/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.
200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7943 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.6864 - val_sparse_categorical_accuracy: 0.5536
# Epoch 105/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7839 - sparse_categorical_accuracy: 0.5152 - val_loss: 1.6912 - val_sparse_categorical_accuracy: 0.5404
# Epoch 106/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7846 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.7577 - val_sparse_categorical_accuracy: 0.5233
# Epoch 107/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7829 - sparse_categorical_accuracy: 0.5174 - val_loss: 1.6802 - val_sparse_categorical_accuracy: 0.5549
# Epoch 108/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7777 - sparse_categorical_accuracy: 0.5164 - val_loss: 1.6839 - val_sparse_categorical_accuracy: 0.5560
# Epoch 109/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7777 - sparse_categorical_accuracy: 0.5171 - val_loss: 1.8327 - val_sparse_categorical_accuracy: 0.4999
# Epoch 110/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7834 - sparse_categorical_accuracy: 0.5170 - val_loss: 1.8751 - val_sparse_categorical_accuracy: 0.4903
# Epoch 111/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7840 - sparse_categorical_accuracy: 0.5163 - val_loss: 1.6886 - val_sparse_categorical_accuracy: 0.5460
# Epoch 112/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7840 - sparse_categorical_accuracy: 0.5187 - val_loss: 1.8562 - val_sparse_categorical_accuracy: 0.5192
# Epoch 113/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7848 - sparse_categorical_accuracy: 0.5196 - val_loss: 1.6783 - val_sparse_categorical_accuracy: 0.5533
# Epoch 114/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7863 - sparse_categorical_accuracy: 0.5183 - val_loss: 1.7589 - val_sparse_categorical_accuracy: 0.5352
# Epoch 115/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7865 - sparse_categorical_accuracy: 0.5201 - val_loss: 1.7553 - val_sparse_categorical_accuracy: 0.5374
# Epoch 116/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7855 - sparse_categorical_accuracy: 0.5235 - val_loss: 1.7457 - val_sparse_categorical_accuracy: 0.5245
# Epoch 117/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7812 - sparse_categorical_accuracy: 0.5250 - val_loss: 1.7608 - val_sparse_categorical_accuracy: 0.5259
# Epoch 118/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7771 - sparse_categorical_accuracy: 0.5254 - val_loss: 1.8748 - val_sparse_categorical_accuracy: 0.4838
# Epoch 119/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7731 - sparse_categorical_accuracy: 0.5294 - val_loss: 1.8480 - val_sparse_categorical_accuracy: 0.5028
# Epoch 120/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7721 - sparse_categorical_accuracy: 0.5285 - val_loss: 1.7056 - val_sparse_categorical_accuracy: 0.5467
# Epoch 121/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7788 - sparse_categorical_accuracy: 0.5280 - val_loss: 1.8147 - val_sparse_categorical_accuracy: 0.5234
# Epoch 122/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7763 - sparse_categorical_accuracy: 0.5307 - val_loss: 1.8358 - val_sparse_categorical_accuracy: 0.5184
# Epoch 123/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7726 - sparse_categorical_accuracy: 0.5289 - val_loss: 1.6703 - val_sparse_categorical_accuracy: 0.5567
# Epoch 124/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7814 - sparse_categorical_accuracy: 0.5293 - val_loss: 1.7655 - val_sparse_categorical_accuracy: 0.5354
# Epoch 125/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7767 - sparse_categorical_accuracy: 0.5297 - val_loss: 1.8058 - val_sparse_categorical_accuracy: 0.5206
# Epoch 126/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7771 - sparse_categorical_accuracy: 0.5329 - val_loss: 1.7022 - val_sparse_categorical_accuracy: 0.5548
# Epoch 127/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7729 - sparse_categorical_accuracy: 0.5336 - val_loss: 1.8487 - val_sparse_categorical_accuracy: 0.5175
# Epoch 128/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7800 - sparse_categorical_accuracy: 0.5314 - val_loss: 1.6707 - val_sparse_categorical_accuracy: 0.5695
# Epoch 129/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7749 - sparse_categorical_accuracy: 0.5355 - val_loss: 1.6497 - val_sparse_categorical_accuracy: 0.5765
# Epoch 130/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7832 - sparse_categorical_accuracy: 0.5320 - val_loss: 1.7070 - val_sparse_categorical_accuracy: 0.5485
# Epoch 131/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7818 - sparse_categorical_accuracy: 0.5347 - val_loss: 1.8105 - val_sparse_categorical_accuracy: 0.5341
# Epoch 132/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7768 - sparse_categorical_accuracy: 0.5333 - val_loss: 1.6845 - val_sparse_categorical_accuracy: 0.5671
# Epoch 133/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7880 - sparse_categorical_accuracy: 0.5329 - val_loss: 1.7565 - val_sparse_categorical_accuracy: 0.5362
# Epoch 134/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7817 - sparse_categorical_accuracy: 0.5365 - val_loss: 1.6986 - val_sparse_categorical_accuracy: 0.5642
# Epoch 135/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - loss: 1.7708 - sparse_categorical_accuracy: 0.5379 - val_loss: 1.7300 - val_sparse_categorical_accuracy: 0.5371
# Epoch 136/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7827 - sparse_categorical_accuracy: 0.5339 - val_loss: 1.7800 - val_sparse_categorical_accuracy: 0.5484
# Epoch 137/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7800 - sparse_categorical_accuracy: 0.5367 - val_loss: 1.6468 - val_sparse_categorical_accuracy: 0.5747
# Epoch 138/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7779 - sparse_categorical_accuracy: 0.5380 - val_loss: 1.7404 - val_sparse_categorical_accuracy: 0.5487
# Epoch 139/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7692 - sparse_categorical_accuracy: 0.5410 - val_loss: 1.6893 - val_sparse_categorical_accuracy: 0.5645
# Epoch 140/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7742 - sparse_categorical_accuracy: 0.5391 - val_loss: 1.7380 - val_sparse_categorical_accuracy: 0.5572
# Epoch 141/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7734 - sparse_categorical_accuracy: 0.5368 - val_loss: 1.7143 - val_sparse_categorical_accuracy: 0.5606
# Epoch 142/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7693 - sparse_categorical_accuracy: 0.5425 - val_loss: 1.8434 - val_sparse_categorical_accuracy: 0.5105
# Epoch 143/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7747 - sparse_categorical_accuracy: 0.5378 - val_loss: 1.7879 - val_sparse_categorical_accuracy: 0.5445
# Epoch 144/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7773 - sparse_categorical_accuracy: 0.5420 - val_loss: 1.8990 - val_sparse_categorical_accuracy: 0.5016
# Epoch 145/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7765 - sparse_categorical_accuracy: 0.5414 - val_loss: 1.6492 - val_sparse_categorical_accuracy: 0.5853
# Epoch 146/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7694 - sparse_categorical_accuracy: 0.5429 - val_loss: 1.6934 - val_sparse_categorical_accuracy: 0.5751
# Epoch 147/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - loss: 1.7571 - sparse_categorical_accuracy: 0.5463 - val_loss: 1.7836 - val_sparse_categorical_accuracy: 0.5329
# Epoch 148/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7594 - sparse_categorical_accuracy: 0.5466 - val_loss: 1.6876 - val_sparse_categorical_accuracy: 0.5654
# Epoch 149/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7596 - sparse_categorical_accuracy: 0.5451 - val_loss: 1.6723 - val_sparse_categorical_accuracy: 0.5734
# Epoch 150/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7582 - sparse_categorical_accuracy: 0.5486 - val_loss: 1.8082 - val_sparse_categorical_accuracy: 0.5268
# Epoch 151/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7634 - sparse_categorical_accuracy: 0.5473 - val_loss: 1.7332 - val_sparse_categorical_accuracy: 0.5525
# Epoch 152/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7708 - sparse_categorical_accuracy: 0.5436 - val_loss: 1.7044 - val_sparse_categorical_accuracy: 0.5599
# Epoch 153/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7656 - sparse_categorical_accuracy: 0.5476 - val_loss: 1.7470 - val_sparse_categorical_accuracy: 0.5499
# Epoch 154/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7566 - sparse_categorical_accuracy: 0.5465 - val_loss: 1.8425 - val_sparse_categorical_accuracy: 0.5265
# Epoch 155/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7566 - sparse_categorical_accuracy: 0.5479 - val_loss: 1.7598 - val_sparse_categorical_accuracy: 0.5567
# Epoch 156/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7544 - sparse_categorical_accuracy: 0.5516 - val_loss: 1.6093 - val_sparse_categorical_accuracy: 0.5911
# Epoch 157/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7578 - sparse_categorical_accuracy: 0.5517 - val_loss: 1.8290 - val_sparse_categorical_accuracy: 0.5273
# Epoch 158/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7530 - sparse_categorical_accuracy: 0.5539 - val_loss: 1.6972 - val_sparse_categorical_accuracy: 0.5790
# Epoch 159/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7567 - sparse_categorical_accuracy: 0.5515 - val_loss: 1.7737 - val_sparse_categorical_accuracy: 0.5528
# Epoch 160/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7507 - sparse_categorical_accuracy: 0.5558 - val_loss: 1.7758 - val_sparse_categorical_accuracy: 0.5498
# Epoch 161/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.7569 - sparse_categorical_accuracy: 0.5547 - val_loss: 1.7809 - val_sparse_categorical_accuracy: 0.5415
# Epoch 162/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7588 - sparse_categorical_accuracy: 0.5538 - val_loss: 1.6386 - val_sparse_categorical_accuracy: 0.5899
# Epoch 163/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7502 - sparse_categorical_accuracy: 0.5553 - val_loss: 1.6970 - val_sparse_categorical_accuracy: 0.5752
# Epoch 164/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7521 - sparse_categorical_accuracy: 0.5541 - val_loss: 1.6292 - val_sparse_categorical_accuracy: 0.5943
# Epoch 165/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7539 - sparse_categorical_accuracy: 0.5559 - val_loss: 1.8147 - val_sparse_categorical_accuracy: 0.5377
# Epoch 166/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7486 - sparse_categorical_accuracy: 0.5580 - val_loss: 1.6607 - val_sparse_categorical_accuracy: 0.5815
# Epoch 167/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7550 - sparse_categorical_accuracy: 0.5543 - val_loss: 1.6518 - val_sparse_categorical_accuracy: 0.5853
# Epoch 168/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7513 - sparse_categorical_accuracy: 0.5579 - val_loss: 1.6507 - val_sparse_categorical_accuracy: 0.5862
# Epoch 169/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - loss: 1.7531 - sparse_categorical_accuracy: 0.5567 - val_loss: 1.6663 - val_sparse_categorical_accuracy: 0.5923
# Epoch 170/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7516 - sparse_categorical_accuracy: 0.5572 - val_loss: 1.7395 - val_sparse_categorical_accuracy: 0.5636
# Epoch 171/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7538 - sparse_categorical_accuracy: 0.5588 - val_loss: 1.7634 - val_sparse_categorical_accuracy: 0.5613
# Epoch 172/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7502 - sparse_categorical_accuracy: 0.5588 - val_loss: 1.6782 - val_sparse_categorical_accuracy: 0.5873
# Epoch 173/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7499 - sparse_categorical_accuracy: 0.5587 - val_loss: 1.6606 - val_sparse_categorical_accuracy: 0.5855
# Epoch 174/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7496 - sparse_categorical_accuracy: 0.5594 - val_loss: 1.7239 - val_sparse_categorical_accuracy: 0.5618
# Epoch 175/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7507 - sparse_categorical_accuracy: 0.5580 - val_loss: 1.6627 - val_sparse_categorical_accuracy: 0.5894
# Epoch 176/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7515 - sparse_categorical_accuracy: 0.5588 - val_loss: 1.6828 - val_sparse_categorical_accuracy: 0.5833
# Epoch 177/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7480 - sparse_categorical_accuracy: 0.5627 - val_loss: 1.6789 - val_sparse_categorical_accuracy: 0.5694
# Epoch 178/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7546 - sparse_categorical_accuracy: 0.5562 - val_loss: 1.7741 - val_sparse_categorical_accuracy: 0.5487
# Epoch 179/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7483 - sparse_categorical_accuracy: 0.5606 - val_loss: 1.6459 - val_sparse_categorical_accuracy: 0.5954
# Epoch 180/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7476 - sparse_categorical_accuracy: 0.5577 - val_loss: 1.6796 - val_sparse_categorical_accuracy: 0.5820
# Epoch 181/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7459 - sparse_categorical_accuracy: 0.5609 - val_loss: 1.6694 - val_sparse_categorical_accuracy: 0.5889
# Epoch 182/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7416 - sparse_categorical_accuracy: 0.5627 - val_loss: 1.8432 - val_sparse_categorical_accuracy: 0.5276
# Epoch 183/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7413 - sparse_categorical_accuracy: 0.5614 - val_loss: 1.6720 - val_sparse_categorical_accuracy: 0.5762
# Epoch 184/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7411 - sparse_categorical_accuracy: 0.5654 - val_loss: 1.7195 - val_sparse_categorical_accuracy: 0.5687
# Epoch 185/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7403 - sparse_categorical_accuracy: 0.5653 - val_loss: 1.7785 - val_sparse_categorical_accuracy: 0.5611
# Epoch 186/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7405 - sparse_categorical_accuracy: 0.5692 - val_loss: 1.6173 - val_sparse_categorical_accuracy: 0.6075
# Epoch 187/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7415 - sparse_categorical_accuracy: 0.5656 - val_loss: 1.8117 - val_sparse_categorical_accuracy: 0.5426
# Epoch 188/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7461 - sparse_categorical_accuracy: 0.5633 - val_loss: 1.7031 - val_sparse_categorical_accuracy: 0.5790
# Epoch 189/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7429 - sparse_categorical_accuracy: 0.5680 - val_loss: 1.7635 - val_sparse_categorical_accuracy: 0.5559
# Epoch 190/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7457 - sparse_categorical_accuracy: 0.5667 - val_loss: 1.7060 - val_sparse_categorical_accuracy: 0.5816
# Epoch 191/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7414 - sparse_categorical_accuracy: 0.5677 - val_loss: 1.7073 - val_sparse_categorical_accuracy: 0.5754
# Epoch 192/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7398 - sparse_categorical_accuracy: 0.5677 - val_loss: 1.6265 - val_sparse_categorical_accuracy: 0.6089
# Epoch 193/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7398 - sparse_categorical_accuracy: 0.5667 - val_loss: 1.6803 - val_sparse_categorical_accuracy: 0.5819
# Epoch 194/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7439 - sparse_categorical_accuracy: 0.5672 - val_loss: 1.7581 - val_sparse_categorical_accuracy: 0.5642
# Epoch 195/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7430 - sparse_categorical_accuracy: 0.5686 - val_loss: 1.6992 - val_sparse_categorical_accuracy: 0.5725
# Epoch 196/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.7423 - sparse_categorical_accuracy: 0.5685 - val_loss: 1.7490 - val_sparse_categorical_accuracy: 0.5519
# Epoch 197/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7471 - sparse_categorical_accuracy: 0.5675 - val_loss: 1.6728 - val_sparse_categorical_accuracy: 0.5842
# Epoch 198/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.
200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7914 - sparse_categorical_accuracy: 0.4958 - val_loss: 1.7182 - val_sparse_categorical_accuracy: 0.5207
# Epoch 127/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7946 - sparse_categorical_accuracy: 0.4973 - val_loss: 1.7422 - val_sparse_categorical_accuracy: 0.5163
# Epoch 128/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - loss: 1.7897 - sparse_categorical_accuracy: 0.5007 - val_loss: 1.7379 - val_sparse_categorical_accuracy: 0.5081
# Epoch 129/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - loss: 1.7964 - sparse_categorical_accuracy: 0.4994 - val_loss: 1.7873 - val_sparse_categorical_accuracy: 0.4960
# Epoch 130/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7967 - sparse_categorical_accuracy: 0.4979 - val_loss: 1.8111 - val_sparse_categorical_accuracy: 0.5011
# 8583.060854911804

# %%
history14 = experiment2(dropout_rate=0.4,run_number=4)
# Out:
# Epoch 1/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 14.7558 - sparse_categorical_accuracy: 0.1901 - val_loss: 11.7001 - val_sparse_categorical_accuracy: 0.2601
# Epoch 2/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 9.6502 - sparse_categorical_accuracy: 0.2579 - val_loss: 7.8727 - val_sparse_categorical_accuracy: 0.2718
# Epoch 3/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 6.6723 - sparse_categorical_accuracy: 0.2821 - val_loss: 5.5981 - val_sparse_categorical_accuracy: 0.3085
# Epoch 4/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - loss: 4.8988 - sparse_categorical_accuracy: 0.2984 - val_loss: 4.2447 - val_sparse_categorical_accuracy: 0.3263
# Epoch 5/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 3.8302 - sparse_categorical_accuracy: 0.3068 - val_loss: 3.4011 - val_sparse_categorical_accuracy: 0.3391
# Epoch 6/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 3.1543 - sparse_categorical_accuracy: 0.3176 - val_loss: 2.8454 - val_sparse_categorical_accuracy: 0.3467
# Epoch 7/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 2.7242 - sparse_categorical_accuracy: 0.3258 - val_loss: 2.5044 - val_sparse_categorical_accuracy: 0.3618
# Epoch 8/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 2.4456 - sparse_categorical_accuracy: 0.3356 - val_loss: 2.3509 - val_sparse_categorical_accuracy: 0.3561
# Epoch 9/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 2.2688 - sparse_categorical_accuracy: 0.3385 - val_loss: 2.1935 - val_sparse_categorical_accuracy: 0.3509
# Epoch 10/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 2.1490 - sparse_categorical_accuracy: 0.3511 - val_loss: 2.0737 - val_sparse_categorical_accuracy: 0.3570
# Epoch 11/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 2.0642 - sparse_categorical_accuracy: 0.3537 - val_loss: 1.9449 - val_sparse_categorical_accuracy: 0.3906
# Epoch 12/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 2.0073 - sparse_categorical_accuracy: 0.3605 - val_loss: 1.9591 - val_sparse_categorical_accuracy: 0.3738
# Epoch 13/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - loss: 1.9723 - sparse_categorical_accuracy: 0.3661 - val_loss: 1.9841 - val_sparse_categorical_accuracy: 0.3791
# Epoch 14/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.9432 - sparse_categorical_accuracy: 0.3763 - val_loss: 1.9454 - val_sparse_categorical_accuracy: 0.3778
# Epoch 15/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.9216 - sparse_categorical_accuracy: 0.3798 - val_loss: 1.8731 - val_sparse_categorical_accuracy: 0.3966
# Epoch 16/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.9106 - sparse_categorical_accuracy: 0.3842 - val_loss: 1.8361 - val_sparse_categorical_accuracy: 0.3978
# Epoch 17/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.8979 - sparse_categorical_accuracy: 0.3895 - val_loss: 1.8569 - val_sparse_categorical_accuracy: 0.4031
# Epoch 18/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 1.
200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7595 - sparse_categorical_accuracy: 0.4914 - val_loss: 1.7963 - val_sparse_categorical_accuracy: 0.4876
# Epoch 90/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7604 - sparse_categorical_accuracy: 0.4904 - val_loss: 1.7679 - val_sparse_categorical_accuracy: 0.4931
# Epoch 91/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7552 - sparse_categorical_accuracy: 0.4949 - val_loss: 1.7011 - val_sparse_categorical_accuracy: 0.5203
# Epoch 92/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7490 - sparse_categorical_accuracy: 0.4972 - val_loss: 1.7011 - val_sparse_categorical_accuracy: 0.5131
# Epoch 93/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7500 - sparse_categorical_accuracy: 0.4949 - val_loss: 1.6636 - val_sparse_categorical_accuracy: 0.5221
# Epoch 94/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - loss: 1.7493 - sparse_categorical_accuracy: 0.4945 - val_loss: 1.6587 - val_sparse_categorical_accuracy: 0.5270
# Epoch 95/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7433 - sparse_categorical_accuracy: 0.4995 - val_loss: 1.6490 - val_sparse_categorical_accuracy: 0.5346
# Epoch 96/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7441 - sparse_categorical_accuracy: 0.5007 - val_loss: 1.6687 - val_sparse_categorical_accuracy: 0.5179
# Epoch 97/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7449 - sparse_categorical_accuracy: 0.5000 - val_loss: 1.6989 - val_sparse_categorical_accuracy: 0.5055
# Epoch 98/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7439 - sparse_categorical_accuracy: 0.5030 - val_loss: 1.7506 - val_sparse_categorical_accuracy: 0.5055
# Epoch 99/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7441 - sparse_categorical_accuracy: 0.4978 - val_loss: 1.6340 - val_sparse_categorical_accuracy: 0.5461
# Epoch 100/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - loss: 1.7315 - sparse_categorical_accuracy: 0.5052 - val_loss: 1.6149 - val_sparse_categorical_accuracy: 0.5496
# Epoch 101/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7301 - sparse_categorical_accuracy: 0.5061 - val_loss: 1.6675 - val_sparse_categorical_accuracy: 0.5189
# Epoch 102/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7369 - sparse_categorical_accuracy: 0.5045 - val_loss: 1.6896 - val_sparse_categorical_accuracy: 0.5190
# Epoch 103/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7384 - sparse_categorical_accuracy: 0.5053 - val_loss: 1.6949 - val_sparse_categorical_accuracy: 0.5238
# Epoch 104/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7300 - sparse_categorical_accuracy: 0.5092 - val_loss: 1.6496 - val_sparse_categorical_accuracy: 0.5432
# Epoch 105/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7274 - sparse_categorical_accuracy: 0.5086 - val_loss: 1.9032 - val_sparse_categorical_accuracy: 0.4655
# Epoch 106/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7269 - sparse_categorical_accuracy: 0.5099 - val_loss: 1.6618 - val_sparse_categorical_accuracy: 0.5293
# Epoch 107/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7241 - sparse_categorical_accuracy: 0.5113 - val_loss: 1.7733 - val_sparse_categorical_accuracy: 0.4813
# Epoch 108/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7321 - sparse_categorical_accuracy: 0.5105 - val_loss: 1.6286 - val_sparse_categorical_accuracy: 0.5441
# Epoch 109/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - loss: 1.7256 - sparse_categorical_accuracy: 0.5105 - val_loss: 1.6332 - val_sparse_categorical_accuracy: 0.5471
# Epoch 110/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7318 - sparse_categorical_accuracy: 0.5115 - val_loss: 1.7232 - val_sparse_categorical_accuracy: 0.5243
# Epoch 111/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7302 - sparse_categorical_accuracy: 0.5102 - val_loss: 1.6566 - val_sparse_categorical_accuracy: 0.5333
# Epoch 112/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7311 - sparse_categorical_accuracy: 0.5110 - val_loss: 1.6623 - val_sparse_categorical_accuracy: 0.5399
# Epoch 113/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7277 - sparse_categorical_accuracy: 0.5155 - val_loss: 1.6774 - val_sparse_categorical_accuracy: 0.5323
# Epoch 114/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7253 - sparse_categorical_accuracy: 0.5142 - val_loss: 1.7494 - val_sparse_categorical_accuracy: 0.4988
# Epoch 115/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - loss: 1.7356 - sparse_categorical_accuracy: 0.5126 - val_loss: 1.6353 - val_sparse_categorical_accuracy: 0.5488
# Epoch 116/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7283 - sparse_categorical_accuracy: 0.5166 - val_loss: 1.6437 - val_sparse_categorical_accuracy: 0.5337
# Epoch 117/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7220 - sparse_categorical_accuracy: 0.5192 - val_loss: 1.7945 - val_sparse_categorical_accuracy: 0.4977
# Epoch 118/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7312 - sparse_categorical_accuracy: 0.5163 - val_loss: 1.6973 - val_sparse_categorical_accuracy: 0.5348
# Epoch 119/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7318 - sparse_categorical_accuracy: 0.5158 - val_loss: 1.7094 - val_sparse_categorical_accuracy: 0.5260
# Epoch 120/200
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - loss: 1.7359 - sparse_categorical_accuracy: 0.5167 - val_loss: 1.7200 - val_sparse_categorical_accuracy: 0.5256
# 7942.436579465866

# %% [markdown]
# ### Question 2 (Total 15 marks)

# %% [markdown]
# SWA-Gaussian (SWAG) is another Bayesian neural network approach that builds on Stochastic Weight Averaging (SWA) by using model weights collected during a final phase of training to fit a Gaussian distribution as the approximation to the posterior distribution.
#
# * Maddox, W. J., Izmailov, P., Garipov, T., Vetroc, D. P. and Wilson, A. G. (2019), "A Simple Baseline for Bayesian Uncertainty in Deep Learning", _Advances in Neural Information Processing Systems_, **32**, 2019.
# * Izmailov, P., Podoprikhin, D., Garipov, T., Vetrov, D., and Wilson, A. G. (2018), "Averaging weights leads to wider optima and better generalization", in _Uncertainty in Artificial Intelligence (UAI)_, 876-885.
#
# The process consists of two main phases:
#
# 1. A first phase of standard training to convergence, or use a pre-trained model.
# 2. A second stage (the SWA phase) where the training is continued, using a high constant or cyclical learning rate, typically using SGD with momentum. In this phase, the training explores the region surrounding the local optimum in weight space. Let $\theta_i$ denote the model weights after epoch $i$ in the SWA phase. The algorithm maintains a running average of the weights after $T$ epochs of this phase $\overline{\theta}_T := \frac{1}{T}\sum_{i=1}^T \theta_i$, and a running average of the squared weights $(\overline{\theta^2})_T := \frac{1}{T}\sum_{i=1}^T \theta^2_i$. It also stores a deviation matrix $D$, with columns $D_i = (\theta_i - \overline{\theta}_i)$, so that after $T$ epochs in this phase, $D$ will have $p$ rows and $T$ columns, where $p$ is the total number of trainable parameters in the model.
#
# Once the two stages above are complete, the posterior approximation is given by a Gaussian distribution with mean $\overline{\theta}_T$ (also referred to as the SWA solution $\theta_{SWA}$), and whose covariance matrix is given by $\frac{1}{2}(\Sigma_{\text{diag}} + \Sigma_{\text{low-rank}})$. $\Sigma_{\text{diag}}$ is a diagonal matrix given by $\Sigma_{\text{diag}} := \text{diag}((\overline{\theta^2})_T - (\overline{\theta}_T)^2)$. $\Sigma_{\text{low-rank}}$ is a low-rank estimate of the covariance matrix which uses the last $K$ columns of $D$, corresponding to the last $K$ epochs of training. $\Sigma_{\text{low-rank}}$ is then given by $\Sigma_{\text{low-rank}} := \frac{1}{K-1}\hat{D}\hat{D}^T$, where $\hat{D}$ is the matrix with columns equal to $D_i$ for $i=T − K + 1,\ldots, T$.  $K$ is the rank of the resulting approximation and is a hyperparameter of the method.

# %% [markdown]
# a) You should implement a custom Keras callback to handle the SWAG collection process (phase 2 above). Your custom callback will be used within a regular `model.fit` call, and should be used to collect the running averages of the model weights, as well as the running averages of the squared weights, and the deviation matrix. The running averages and deviation matrix should be updated at the end of every epoch. You can assume that phase 1 above has already been completed, so that the model that is used with the custom callback is starting from a pre-trained state.
#
# You may find it helpful to break your custom callback implementation down using helper functions or classes.
#
# **(6 marks)**

# %%
class SWACallback(keras.callbacks.Callback):

  def __init__(self,n_params,T,K,testing):
    super().__init__()
    self.d = n_params
    self.T = T
    self.K = K
    self.testing = testing
    self.running_avg_weights = keras.ops.zeros(self.d)
    self.running_avg_squared_weights = keras.ops.zeros(self.d)
    self.deviation_matrix = keras.ops.zeros((self.d,self.T))
    self.model_shape = None

  def on_epoch_end(self, epoch, logs=None):

    # Get weights and set the structure of the model
    current_weights = self.model.get_weights()
    if epoch==0:
      self.model_shape = self.get_model_shape(current_weights)

    # Flatten all one weights to 1D array for averages and deviation matrix
    flattened_weights = self.flatten_weights(current_weights)

    self.running_avg_weights = self.running_avg_weights + 1/(epoch+1)*(flattened_weights - self.running_avg_weights)
    self.running_avg_squared_weights = self.running_avg_squared_weights + 1/(epoch+1)*(ops.square(flattened_weights) - self.running_avg_squared_weights)

    deviation = flattened_weights - self.running_avg_weights
    self.deviation_matrix[:,epoch] = deviation

  def on_test_batch_begin(self,batch,logs=None):
    # Use flag to make sure this only happens on model evaluation (not on validation)
    if self.testing==True:

      z1 = keras.random.normal((self.d,))
      z2 = keras.random.normal((self.K,))

      d_hat = self.deviation_matrix[:,self.T-self.K:]
      # Account for numerical instability by taking maximum of sigma_diag and a small number
      sample_variance = self.running_avg_squared_weights - keras.ops.square(self.running_avg_weights)
      sigma_diag = keras.ops.sqrt(keras.ops.maximum(sample_variance,1e-20))
      second_term = 1/2**(1/2)*(sigma_diag*z1)
      third_term = 1/(2*(K-1))**(1/2)*keras.ops.matmul(d_hat,z2)
      theta = self.running_avg_weights + second_term + third_term

      model_weights = self.reshape_weights(theta)
      self.model.set_weights(model_weights)

  # Flatten parameters for running averages and deviation matrix
  def flatten_weights(self,weights):
    flattened_weights = weights[0].flatten()
    for i in range(1,len(weights)):
      flattened_weights = keras.ops.concatenate((flattened_weights, weights[i].flatten()))
    return flattened_weights

  def reshape_weights(self,theta):
    model_weights = []
    index = 0
    # For each layer in the model
    for i in range(len(self.model_shape)):
      # Get the length of the layer and extract relevant components from theta
      layer_shape = self.model_shape[i]
      length = keras.ops.prod(layer_shape)
      current_weights = theta[index:index+length].reshape(layer_shape)
      model_weights.append(current_weights)
      index += length
    return model_weights

  def get_model_shape(self,weights):
      model_shape = []
      for array in weights:
        model_shape.append(array.shape)
      return model_shape

# %% [markdown]
# b) Use your custom callback with the pre-trained (deterministic) model from question 1b) and 1c).
#
# You should load the saved best model, and run additional epochs of training, using the `.fit()` method and your custom callback to collect the running averages and deviation matrix required for the SWAG posterior approximation. It is recommended to save the model weights that are used in this approximation. You should collect at least 20 snapshots (i.e. $K\ge 20$) of the model weights.
#
# _If you were not able to implement the architecture specified in 1b) you can still complete this question (and following questions) using trained classifier model with an alternative architecture._
#
# **(4 marks)**

# %%
model2 = keras.saving.load_model('/content/drive/MyDrive/deep_learning_cw2/run_3/run_3.keras',
                        custom_objects={"ResidualBlock": ResidualBlock})

# %%
T = 20
K = 20
n_params = model2.count_params()
swa_callback = SWACallback(n_params, T, K, testing=False)

# %%
new_lr = 0.01
model2.optimizer.learning_rate.assign(new_lr)
# Out:
# tensor(0.0100, device='cuda:0')

# %%
history = model2.fit(train_data_loader,epochs=T,validation_data=val_data_loader,callbacks=[swa_callback])
# Out:
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5322 - sparse_categorical_accuracy: 0.6475 - val_loss: 1.5178 - val_sparse_categorical_accuracy: 0.6455
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5379 - sparse_categorical_accuracy: 0.6462 - val_loss: 1.4415 - val_sparse_categorical_accuracy: 0.6773
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5280 - sparse_categorical_accuracy: 0.6471 - val_loss: 1.5584 - val_sparse_categorical_accuracy: 0.6364
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5327 - sparse_categorical_accuracy: 0.6492 - val_loss: 1.4982 - val_sparse_categorical_accuracy: 0.6502
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5223 - sparse_categorical_accuracy: 0.6513 - val_loss: 1.6202 - val_sparse_categorical_accuracy: 0.6217
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 102ms/step - loss: 1.5260 - sparse_categorical_accuracy: 0.6483 - val_loss: 1.5652 - val_sparse_categorical_accuracy: 0.6367
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5184 - sparse_categorical_accuracy: 0.6499 - val_loss: 1.4598 - val_sparse_categorical_accuracy: 0.6682
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5199 - sparse_categorical_accuracy: 0.6489 - val_loss: 1.5490 - val_sparse_categorical_accuracy: 0.6410
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5197 - sparse_categorical_accuracy: 0.6510 - val_loss: 1.4954 - val_sparse_categorical_accuracy: 0.6567
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5096 - sparse_categorical_accuracy: 0.6540 - val_loss: 1.4781 - val_sparse_categorical_accuracy: 0.6637
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5081 - sparse_categorical_accuracy: 0.6557 - val_loss: 1.4598 - val_sparse_categorical_accuracy: 0.6693
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5084 - sparse_categorical_accuracy: 0.6535 - val_loss: 1.5756 - val_sparse_categorical_accuracy: 0.6294
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 102ms/step - loss: 1.5119 - sparse_categorical_accuracy: 0.6553 - val_loss: 1.4981 - val_sparse_categorical_accuracy: 0.6564
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.5067 - sparse_categorical_accuracy: 0.6563 - val_loss: 1.4422 - val_sparse_categorical_accuracy: 0.6778
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5080 - sparse_categorical_accuracy: 0.6571 - val_loss: 1.4482 - val_sparse_categorical_accuracy: 0.6729
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.4972 - sparse_categorical_accuracy: 0.6592 - val_loss: 1.5218 - val_sparse_categorical_accuracy: 0.6417
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.4995 - sparse_categorical_accuracy: 0.6598 - val_loss: 1.4243 - val_sparse_categorical_accuracy: 0.6794
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 101ms/step - loss: 1.5018 - sparse_categorical_accuracy: 0.6580 - val_loss: 1.4825 - val_sparse_categorical_accuracy: 0.6715
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 63s 100ms/step - loss: 1.4989 - sparse_categorical_accuracy: 0.6569 - val_loss: 1.4312 - val_sparse_categorical_accuracy: 0.6732
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 62s 100ms/step - loss: 1.4955 - sparse_categorical_accuracy: 0.6587 - val_loss: 1.4297 - val_sparse_categorical_accuracy: 0.6891

# %% [markdown]
# c) As described above, in SWAG the posterior approximation is given by the Gaussian distribution $N(\theta_{SWA}, \frac{1}{2}(\Sigma_{\text{diag}} + \Sigma_{\text{low-rank}}))$. Parameters $\tilde{\theta}$ can be sampled from this distribution using the following identity
#
# $$\tilde{\theta} = \theta_{SWA} + \frac{1}{\sqrt{2}} \Sigma_{\text{diag}}^{\frac{1}{2}} z_1 + \frac{1}{\sqrt{2(K-1)}} \hat{D} z_2,\qquad \text{with }z_1\sim N(\mathbf{0},\mathbf{I}_d),~z_2\sim N(\mathbf{0},\mathbf{I}_K),$$
#
# where $d$ is the number of parameters in the network.
#
# Compute the test loss and accuracy for the SWAG model, using the above identity to sample a single set of parameters per batch of data examples (using an ensemble size of one).
#
# **(5 marks)**

# %% [markdown]
# Relevant pieces of code are included inside the callback (in particular on_test_batch_begin method):

# %%
swa_callback.testing=True
model2.evaluate(test_data_loader,callbacks=[swa_callback])
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 1.5658 - sparse_categorical_accuracy: 0.6371
# [1.5658307075500488, 0.6370999813079834]

# %%
model2.save('/content/drive/MyDrive/deep_learning_cw2/swag_using_run3/swag_3.keras')

# %% [markdown]
# ### Question 3 (Total 10 marks)

# %% [markdown]
# Recall that with Bayesian neural networks, once we have our posterior distribution approximation $q_\phi(\theta)$, we can compute the predictive distribution by drawing multiple $S$ samples from the approximate posterior:
#
# $$p(y^* \mid x^*, \mathcal{D}) \approx \frac{1}{S} \sum_{s=1}^S p(y^* \mid x^*, \theta_s),\qquad \theta_s\sim q_\phi(\theta).$$

# %% [markdown]
# a) Use the predictive distribution with $S\ge30$ to compute the test loss and accuracy for the MC Dropout model of question 1d) as well as the SWAG model of question 2.
#
# **(3 marks)**

# %%
mc_model = keras.saving.load_model('/content/drive/MyDrive/deep_learning_cw2/mc_model_run_2/run_2.keras',
                        custom_objects={"MCResidualBlock": MCResidualBlock})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/operation.py in from_config(cls, config)
#     316         try:
# --> 317             return cls(**config)
#     318         except Exception as e:
#
# TypeError: MCResidualBlock.__init__() missing 1 required positional argument: 'dropout_rate'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     732         try:
# --> 733             instance = cls.from_config(inner_config)
#     734         except TypeError as e:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/ops/operation.py in from_config(cls, config)
#     318         except Exception as e:
# --> 319             raise TypeError(
#     320                 f"Error when deserializing class '{cls.__name__}' using "
#
# TypeError: Error when deserializing class 'MCResidualBlock' using config={'name': 'mc_residual_block_9', 'trainable': True, 'dtype': 'float32', 'filters': 16, 'stride': 1, 'extra_conv': False}.
#
# Exception encountered: MCResidualBlock.__init__() missing 1 required positional argument: 'dropout_rate'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     732         try:
# --> 733             instance = cls.from_config(inner_config)
#     734         except TypeError as e:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/models/sequential.py in from_config(cls, config, custom_objects)
#     370             else:
# --> 371                 layer = serialization_lib.deserialize_keras_object(
#     372                     layer_config,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     734         except TypeError as e:
# --> 735             raise TypeError(
#     736                 f"{cls} could not be deserialized properly. Please"
#
# TypeError: <class '__main__.MCResidualBlock'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': None, 'class_name': 'MCResidualBlock', 'config': {'name': 'mc_residual_block_9', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 137678607978992}, 'filters': 16, 'stride': 1, 'extra_conv': False}, 'registered_name': 'MyLayers>MCResidualBlock', 'build_config': {'shapes_dict': {}}}.
#
# Exception encountered: Error when deserializing class 'MCResidualBlock' using config={'name': 'mc_residual_block_9', 'trainable': True, 'dtype': 'float32', 'filters': 16, 'stride': 1, 'extra_conv': False}.
#
# Exception encountered: MCResidualBlock.__init__() missing 1 required positional argument: 'dropout_rate'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_600/3994682581.py in <cell line: 0>()
# ----> 1 mc_model = keras.saving.load_model('/content/drive/MyDrive/deep_learning_cw2/mc_model_run_2/run_2.keras',
#       2                         custom_objects={"MCResidualBlock": MCResidualBlock})
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     187
#     188     if is_keras_zip or is_keras_dir or is_hf:
# --> 189         return saving_lib.load_model(
#     190             filepath,
#     191             custom_objects=custom_objects,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py in load_model(filepath, custom_objects, compile, safe_mode)
#     363             )
#     364         with open(filepath, "rb") as f:
# --> 365             return _load_model_from_fileobj(
#     366                 f, custom_objects, compile, safe_mode
#     367             )
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py in _load_model_from_fileobj(fileobj, custom_objects, compile, safe_mode)
#     440             config_json = f.read()
#     441
# --> 442         model = _model_from_config(
#     443             config_json, custom_objects, compile, safe_mode
#     444         )
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py in _model_from_config(config_json, custom_objects, compile, safe_mode)
#     429     # Construct the model from the configuration file in the archive.
#     430     with ObjectSharingScope():
# --> 431         model = deserialize_keras_object(
#     432             config_dict, custom_objects, safe_mode=safe_mode
#     433         )
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     733             instance = cls.from_config(inner_config)
#     734         except TypeError as e:
# --> 735             raise TypeError(
#     736                 f"{cls} could not be deserialized properly. Please"
#     737                 " ensure that components that are Python object"
#
# TypeError: <class 'keras.src.models.sequential.Sequential'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras', 'class_name': 'Sequential', 'config': {'name': 'sequential_3', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 137678607978992}, 'layers': [{'module': 'keras.layers', 'class_name': 'InputLayer', 'config': {'batch_shape': [None, 32, 32, 3], 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_layer_3', 'optional': False}, 'registered_name': None}, {'module': 'keras.layers', 'class_name': 'Conv2D', 'config': {'name': 'conv2d_63', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 16, 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'HeNormal', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': {'module': 'keras.regularizers', 'class_name': 'L2', 'config': {'l2': 0.01}, 'registered_name': None}, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': [None, 32, 32, 3]}}, {'module': 'keras.layers', 'class_...
#
# Exception encountered: <class '__main__.MCResidualBlock'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': None, 'class_name': 'MCResidualBlock', 'config': {'name': 'mc_residual_block_9', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 137678607978992}, 'filters': 16, 'stride': 1, 'extra_conv': False}, 'registered_name': 'MyLayers>MCResidualBlock', 'build_config': {'shapes_dict': {}}}.
#
# Exception encountered: Error when deserializing class 'MCResidualBlock' using config={'name': 'mc_residual_block_9', 'trainable': True, 'dtype': 'float32', 'filters': 16, 'stride': 1, 'extra_conv': False}.
#
# Exception encountered: MCResidualBlock.__init__() missing 1 required positional argument: 'dropout_rate'

# %% [markdown]
# Function to estimate the predictive distribution for a batch of examples (callback is needed for SWAG so that we can sample parameters from the posterior):

# %%
def predictive_distribution(model,inputs,S,callbacks):
  output_distributions = []
  for i in range(S):
    # Use batch size = 64 (equal to the size of inputs) so that we only sample one set of parameters
    logits = model.predict(inputs,batch_size=64,callbacks=callbacks)
    output_distributions.append(ops.softmax(logits,axis=-1))
  predictive_distribution = ops.mean(output_distributions,axis=0)
  return predictive_distribution

# %% [markdown]
# Function to compute the accuracy and loss across all examples in the batch:

# %%
def pd_loss_and_accuracy(model,data_loader,S,predictive_distribution_fn,callbacks=None):

  loss_metric = keras.metrics.SparseCategoricalCrossentropy()
  accuracy_metric = keras.metrics.SparseCategoricalAccuracy()

  for inputs,targets in data_loader:
    y_pred = predictive_distribution_fn(model,inputs,S,callbacks)
    loss_metric.update_state(targets,y_pred)
    accuracy_metric.update_state(targets,y_pred)

  final_loss = ops.convert_to_numpy(loss_metric.result())
  final_accuracy = ops.convert_to_numpy(accuracy_metric.result())

  return final_loss, final_accuracy

# %% [markdown]
# Compute test loss and accuracy from predictive distribution of MC Dropout (callbacks are not needed so set to None):

# %%
MC_loss, MC_accuracy = pd_loss_and_accuracy(mc_model,test_data_loader,S=30,
                                            predictive_distribution_fn=predictive_distribution,
                                            callbacks=None)

# %% [markdown]
# Compute test loss and accuracy from predictive distribution of SWAG (callbacks should be the list: [swa_callback])

# %%
swag_loss, swag_accuracy = pd_loss_and_accuracy(swag_model,test_data_loader,S=30,
                                                predictive_distribution_fn=predictive_distribution,
                                                callbacks=[swa_callback])

# %% [markdown]
# #### Expected calibration error
#
# In addition to classification accuracy, probabilistic classifiers should ideally also produce well-calibrated predictions.
#
# A classifier is said to be well-calibrated if the confidence it assigns to its predictions matches how often those predictinos are actually correct. We will define confidence to be the maximum probability output by the model for a given data example. For example, for all predictions made by the model with confidence close to 0.8, we would expect these predictions to be correct approximately 80% of the time. A model that is accurate but over-confident or under-confident is poorly calibrated.
#
# A standard metric for calibration is the **Expected Calibration Error (ECE)**. This is computed as follows:
#
# * Computing all predictions and confidence scores from a model across the test dataset
# * Partition the predictions into confidence bins: divide the interval $[0, 1]$ into equally sized bins $B_m$, $m=1,\ldots,M$
# * For each test example, assign it to the corresponding confidence bin according to the model's confidence score
# * Compute the average accuracy and confidence scores within each confidence bin $B_m$:
#     * Let $\text{acc}(B_m)$ be the fraction of correctly classified examples in the bin
#     * Let $\text{conf}(B_m)$ be the average confidence score of the predictions in the bin
# * The ECE is then given by:
#
# $$ECE = \sum_{m=1}^M \frac{|B_m|}{N} |\text{acc}(B_m) - \text{conf}(B_m)|,$$
#
# where $|B_m|$ is the number of examples in the bin $B_m$, and $N$ is the total number of test examples.
#
# Smaller ECE values indicated better calibration. Perfect calibration would have an ECE score of zero.

# %% [markdown]
# b) Compute and print out the ECE scores for each of the three models developed in this coursework:
#
# * The deterministic CNN model of question 1b) and c)
# * The MC Dropout model of question 1d) (using the predictive distribution with $S\ge30$)
# * The SWAG model of question 2 (using the predictive distribution with $S\ge30$)
#
# Use 20 bins for the ECE calculations in each case.
#
# **(5 marks)**

# %%
cnn_model = keras.saving.load_model('/content/drive/MyDrive/deep_learning_cw2/run_3/run_3.keras',
                        custom_objects={"ResidualBlock": ResidualBlock})

# %%
cnn_model.evaluate(train_data_loader)
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 44ms/step - loss: 1.4592 - sparse_categorical_accuracy: 0.6747
# [1.459211826324463, 0.6747000217437744]

# %%
def ECE_calc(model,test_data_loader,S,callbacks,type):

  # Compute all predictions and confidence scores, and collect corresponding targets

  all_predictions = []
  all_confidences = []
  all_targets = []

  for inputs, targets in test_data_loader:
    if type == "deterministic":
      logits = model.predict(inputs,batch_size=64,verbose=0)
      predictions = ops.softmax(logits,axis=-1)
    else:
      predictions = predictive_distribution(model,inputs,S=30,callbacks=None)
    confidences = ops.max(predictions,axis=-1)
    all_predictions.append(predictions)
    all_confidences.append(confidences)
    all_targets.append(targets)

  all_predictions = ops.concatenate(all_predictions,axis=0)
  all_confidences = ops.concatenate(all_confidences,axis=0)
  all_targets = ops.concatenate(all_targets,axis=0)

  # Group the confidence scores into bins and assign corresponding predictions and targets
  # to the appropriate bin

  binned_predictions = []
  binned_confidences = []
  binned_targets = []
  bin_boundaries = np.linspace(0,1,21)
  for i in range(20):
    binned_confidences.append(all_confidences[(all_confidences>=bin_boundaries[i]) & (all_confidences<bin_boundaries[i+1])])
    binned_predictions.append(all_predictions[(all_confidences>=bin_boundaries[i]) & (all_confidences<bin_boundaries[i+1]),:])
    binned_targets.append(all_targets[(all_confidences>=bin_boundaries[i]) & (all_confidences<bin_boundaries[i+1]),:])

  # Get the accuracy and mean confidence within each bin
  binned_accuracies = []
  average_binned_confidences = []

  for i in range(20):
    accuracy = keras.metrics.SparseCategoricalAccuracy()
    accuracy.update_state(binned_targets[i],binned_predictions[i])
    binned_accuracies.append(accuracy.result())
    if binned_confidences[i].shape[0] == 0:
      average_binned_confidences.append(0)
    else:
      average_binned_confidences.append(ops.mean(binned_confidences[i]))

  # Compute the ECE
  total_examples = 0
  ECE = 0
  for i in range(20):
    bin_examples = len(binned_targets[i])
    total_examples += bin_examples
    ECE += bin_examples*abs(binned_accuracies[i] - average_binned_confidences[i])
  ECE = ECE/total_examples

  # Return binned accuracies and confidences for reliability diagram
  return ECE, binned_accuracies, average_binned_confidences

# %%
ECE, binned_accuracies, average_binned_confidences = ECE_calc(cnn_model,test_data_loader,S=None,callbacks=None,type="deterministic")

# %%
print(ECE)
# Out:
# tensor(0.0202, device='cuda:0')

# %%
print(binned_accuracies)
# Out:
# [tensor(0., device='cuda:0'), tensor(0., device='cuda:0'), tensor(0., device='cuda:0'), tensor(0.0952, device='cuda:0'), tensor(0.2373, device='cuda:0'), tensor(0.3038, device='cuda:0'), tensor(0.3752, device='cuda:0'), tensor(0.4156, device='cuda:0'), tensor(0.4359, device='cuda:0'), tensor(0.4821, device='cuda:0'), tensor(0.5064, device='cuda:0'), tensor(0.5840, device='cuda:0'), tensor(0.6791, device='cuda:0'), tensor(0.7146, device='cuda:0'), tensor(0.7424, device='cuda:0'), tensor(0.7675, device='cuda:0'), tensor(0.8507, device='cuda:0'), tensor(0.8758, device='cuda:0'), tensor(0.9443, device='cuda:0'), tensor(0.9683, device='cuda:0')]

# %%
print(average_binned_confidences)
# Out:
# [0, 0, 0, tensor(0.1885, device='cuda:0'), tensor(0.2291, device='cuda:0'), tensor(0.2778, device='cuda:0'), tensor(0.3263, device='cuda:0'), tensor(0.3750, device='cuda:0'), tensor(0.4257, device='cuda:0'), tensor(0.4752, device='cuda:0'), tensor(0.5245, device='cuda:0'), tensor(0.5759, device='cuda:0'), tensor(0.6262, device='cuda:0'), tensor(0.6749, device='cuda:0'), tensor(0.7244, device='cuda:0'), tensor(0.7757, device='cuda:0'), tensor(0.8256, device='cuda:0'), tensor(0.8755, device='cuda:0'), tensor(0.9258, device='cuda:0'), tensor(0.9776, device='cuda:0')]

# %% [markdown]
# #### Reliability diagram
#
# A related and useful visual representation for a model's calibration is a **reliability diagram**. A reliability diagram shows, for different levels of predicted confidence, how often the model's predictions are actually correct. Following the notation from the previous question, the reliability diagram is a line plot that plots $\text{acc}(B_m)$ (predictive accuracy for bin $B_m$) against $\text{conf}(B_m)$ (average confidence for bin $B_m$).

# %% [markdown]
# c) Make reliability diagrams for each of the same three models as described in part b.
#
# **(2 marks)**

# %%
binned_accuracies_list = []
average_binned_confidences_list = []

for i in range(1,20):
  binned_accuracies_list.append(binned_accuracies[i].cpu().numpy())
  try:
    average_binned_confidences_list.append(average_binned_confidences[i].cpu().numpy())
  except:
    average_binned_confidences_list.append(average_binned_confidences[i])

# %%
plt.plot(binned_accuracies_list, average_binned_confidences_list)
plt.xlabel("Accuracy")
plt.ylabel("Confidence Score")
# Out:
# Text(0, 0.5, 'Confidence Score')

# %% [markdown]
# #### Question 4 (Total 10 marks)

# %% [markdown]
# Provide a separate PDF report with an account of the experiments you have run in this assessment. Your report should include details of the results from all experiments, the hyperparameter settings, and any other choices you have made throughout the development of the models. If you encountered difficulties to successfully train the model(s) you should report these, and if possible suggest what you think might be potential reasons for these difficulties.
#
# Your report should also include your interpretation and analysis of the results, and what you think they might suggest about different models developed in this coursework.
#
# Marks will be awarded for presentation and clarity. Your report should be no more than 2 pages, excluding any references and figures (which can be included in an appendix).
#
# **(10 marks)**
